# %%
import pandas as pd
import numpy as np
import glob, os, yaml, sparse, itertools, subprocess, sys, pickle, re, collections, shutil
from functools import reduce

import scipy.stats as st
import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression, Ridge, RidgeCV, LogisticRegression, LogisticRegressionCV
from sklearn.preprocessing import StandardScaler
import statsmodels.stats.api as stm
import statsmodels.api as sm
from sklearn.utils.class_weight import compute_class_weight

# for survival analysis
import lifelines
from datetime import datetime

from Bio import SeqIO, Entrez
import xml.etree.ElementTree as ET
from dateutil import parser

drug_abbr_dict = {"Delamanid": "DLM",
                  "Bedaquiline": "BDQ",
                  "Clofazimine": "CFZ",
                  "Ethionamide": "ETA",
                  "Linezolid": "LZD",
                  "Moxifloxacin": "MXF",
                  "Capreomycin": "CAP",
                  "Amikacin": "AMI",
                  "Pretomanid": "PTM",
                  "Pyrazinamide": "PZA",
                  "Kanamycin": "KAN",
                  "Levofloxacin": "LEV",
                  "Streptomycin": "STM",
                  "Ethambutol": "EMB",
                  "Isoniazid": "INH",
                  "Rifampicin": "RIF"
                 }

abbr_drug_dict = {val: key for key, val in drug_abbr_dict.items()}

# 7H10 critical concentrations dictionary
cc_dict = {'RIF': 0.5, 'INH': 0.2, 'EMB': 5, 'PZA': 100}

cc_df = pd.read_csv("/n/data1/hms/dbmi/farhat/rollingDB/metadata/MIC/critical_concentrations_WHO_catalog.csv")

drugs_lst = ['RIF', 'INH', 'EMB', 'PZA']

genomic_data_dir = "/n/data1/hms/dbmi/farhat/rollingDB/TRUST/Illumina_culture_WGS_processed"

silent_lst = ['synonymous_variant', 'initiator_codon_variant', 'stop_retained_variant']

# MIC encoding from the TRUST codebook
MIC_encoding_dicts = {'RIF': {1: '0,0.03', 2: '0.03,0.06', 3: '0.06,0.125', 4: '0.125,0.25', 5: '0.25,0.5', 6: '0.5,1', 7: '1,inf'},
                      'INH': {1: '0,0.025', 2: '0.025,0.05', 3: '0.05,0.1', 4: '0.1,0.2', 5: '0.2,inf'},
                      'EMB': {1: '0,0.6', 2: '0.6,1.25', 3: '1.25,2.5', 4: '2.5,5', 5: '5,inf'},
                      'PZA': {1: '0,25', 2: '25,50', 3: '50,75', 4: '75,100', 5: '100,inf'}
                     }

RIF_label_encoding_dict = {1: '≤0.03', 2: '0.03-0.06', 3: '0.06-0.125', 4: '0.125-0.25', 5: '0.25-0.5', 6: '0.5-1', 7: '>1'}
INH_label_encoding_dict = {1: '≤0.025', 2: '0.025-0.05', 3: '0.05-0.1', 4: '0.1-0.2', 5: '>0.2'}
EMB_label_encoding_dict = {1: '≤0.6', 2: '0.6-1.25', 3: '1.25-2.5', 4: '2.5-5', 5: '>5'}
PZA_label_encoding_dict = {1: '≤25', 2: '25-50', 3: '50-75', 4: '75-100', 5: '>100'}

MIC_label_encoding_dicts = {'RIF': RIF_label_encoding_dict, 'INH': INH_label_encoding_dict, 'EMB': EMB_label_encoding_dict, 'PZA': PZA_label_encoding_dict}

df_WGS = pd.read_csv("/n/data1/hms/dbmi/farhat/rollingDB/TRUST/Illumina_culture_WGS_summary.csv")
df_trust_patients = pd.read_csv("../patient_data/combined_patient_WGS_data_contam_control.csv").dropna(subset=['pid', 'Lineage']).reset_index(drop=True)

for i, row in df_trust_patients.iterrows():
    if not pd.isnull(row['Lineage']):
        if type(row['Lineage']) == str:
            if ',' not in row['Lineage']:
                df_trust_patients.loc[i, 'Lineage'] = str(int(float(row['Lineage'])))
        else:
            df_trust_patients.loc[i, 'Lineage'] = str(int(row['Lineage']))
                
df_trust_patients.loc[df_trust_patients['bl_hiv']==0, 'HIV_CD4'] = 0
df_trust_patients.loc[(df_trust_patients['bl_hiv']==1) & (df_trust_patients['bl_cd4'] >= 200), 'HIV_CD4'] = 1
df_trust_patients.loc[(df_trust_patients['bl_hiv']==1) & (df_trust_patients['bl_cd4'] < 200), 'HIV_CD4'] = 2

df_TCC = pd.read_csv("../imputation/TCC.csv")
df_final_outcomes = pd.read_csv("../patient_data/tx_outcomes_table.csv")

out_dir = "/n/data1/hms/dbmi/farhat/Sanjana/TRUST_lowAF"

# %%
df_trust_patients.Lineage.value_counts(dropna=False)

# %%
df_lineage_decontam = extract_lineages(df_WGS.dropna(subset='Lineage'), 'SampleID', out_dir='/n/data1/hms/dbmi/farhat/Sanjana/TRUST_lowAF').rename(columns={'ROLLINGDB_ID': 'SampleID'})

# %%
col = 'F2'

df_compare = df_lineage_decontam[['SampleID', col]].merge(df_WGS[['SampleID', col]].rename(columns={col: f"{col}_old"}))

# %%
df_compare.query(f"{col} != {col}_old")
# Out:
#     SampleID Freschi2020 Freschi2020_old
# 434  MFS-584           4               4
# 435  MFS-585           4               4
# 607  MFS-745           4               4

# %%
sns.scatterplot(data=df_compare,
                x='F2_old',
                y='F2'
               )

plt.xscale('log')
plt.yscale('log')

plt.axvline(0.03, color='darkred', linewidth=0.75)
plt.axhline(0.03, color='darkred', linewidth=0.75)

sns.despine()
plt.show()

# %% [markdown]
# # Get the proportion of NTM reads

# %%
def load_nodes_dmp(nodes_path):
    parent_map = {}
    child_map = {}
    with open(nodes_path, 'r') as f:
        for line in f:
            parts = [x.strip() for x in line.split('|')]
            child_taxid, parent_taxid = int(parts[0]), int(parts[1])
            parent_map[child_taxid] = parent_taxid
            if parent_taxid not in child_map:
                child_map[parent_taxid] = []
            child_map[parent_taxid].append(child_taxid)
    return parent_map, child_map
    

def get_parent_taxids(taxid, parent_map):
    ancestors = []
    while taxid != 1:  # 1 is the root (cellular organisms)
        taxid = parent_map[taxid]
        ancestors.append(taxid)
    return ancestors


def get_child_taxids(taxid, child_map):
    descendants = []
    stack = [taxid]
    while stack:
        current = stack.pop()
        children = child_map.get(current, [])
        descendants.extend(children)
        stack.extend(children)
    return descendants


# analyze taxonomy map 
db_name = '/n/data1/hms/dbmi/farhat/mm774/References/Kraken2_DB_Dir/Kraken2_DB'
parent_map, child_map = load_nodes_dmp(f"{db_name}/taxonomy/nodes.dmp")

taxid = 77643
MTBC_parent_taxids = get_parent_taxids(taxid, parent_map)
MTBC_child_taxids = get_child_taxids(taxid, child_map)

# %% [markdown]
# ```bash
# grep -n 'VH00503:104:AACY2TNM5:1:1306:43737:43843' MFS-409_1.kraken.filtered.fastq | cut -d: -f1 | while read -r lineno; do
#   target=$((lineno + 1))
#   sed -n "${target}p" MFS-409_1.kraken.filtered.fastq
# done
#
# zgrep -n 'VH00503:104:AACY2TNM5:1:1311:23855:8781' MFS-409.R1.trimmed.fastq.gz | cut -d: -f1 | while read -r lineno; do
#   target=$((lineno + 1))
#   zcat MFS-409.R1.trimmed.fastq.gz | sed -n "${target}p"
# done
# ```

# %%
# sample = 'MFS-409'

# kraken_classifications = pd.read_csv(f"{out_dir}/{sample}/{sample}/kraken/kraken_classifications_standard_DB.csv.gz", compression='gzip')
# kraken_classifications.columns = ['C', 'ReadName', 'TaxID', 'ReadLength', 'LCA']

# keep_reads = pd.read_csv(f"{out_dir}/{sample}/{sample}/kraken/keep_read_names.txt", sep='\t', header=None)[0].values

# %%
# len(keep_reads)/len(kraken_classifications)
# Out:
# 0.9044102560374297

# %% [markdown]
# # NTM Proportions

# %%
# mycobacteriaceae family. Some NTMs are in the Mycobacteroides genus, so need to go up to the family level
search_taxid = 1762

# get all children taxa of 1763 that are not children of 77643. Don't add 1762 because the reads mapping to the Mycobacteriaceae family could be from either NTM or MTBC
NTM_taxids = get_child_taxids(search_taxid, child_map)
print(f"{len(NTM_taxids)} Mycobacteriaceae family taxids")

# exclude 1763 because that's not definitive of MTBC vs. NTM. The reads mapping to the Mycobacterium genus could be from either
NTM_taxids = list(set(NTM_taxids) - set(MTBC_child_taxids) - set([77643]) - set([1763]))
print(f"{len(NTM_taxids)} NTM taxids")

NTM_taxids.to_csv("./NTM_taxids.tsv", sep='\t', header=None)
# Out:
# 6572 Mycobacteriaceae family taxids
# 3516 NTM taxids

# %%
NTM_taxids = pd.read_csv("./NTM_taxids.tsv", sep='\t', header=None)[0].values

# df_NTM = pd.DataFrame(columns = ['SampleID', 'NTM_Reads'])
# df_NTM = pd.read_csv("TRUST_lowAF_NTM_read_counts.csv")

# for i, sample in enumerate(os.listdir("/n/data1/hms/dbmi/farhat/Sanjana/TRUST_lowAF")):
    
#     if sample not in df_NTM.SampleID.values:
    
#         num_NTM_reads = len(pd.read_csv(f"/n/data1/hms/dbmi/farhat/Sanjana/TRUST_lowAF/{sample}/{sample}/kraken/kraken_classifications_standard_DB.csv.gz", compression='gzip').query("TaxID in @NTM_taxids"))

#         # num_keep_reads = len(pd.read_csv(f"/n/data1/hms/dbmi/farhat/Sanjana/TRUST_lowAF/{sample}/{sample}/kraken/keep_read_names.txt", sep='\t', header=None))

#         df_NTM.loc[i, :] = [sample, num_NTM_reads]

#         if i % 10 == 0:
#             print(i)
#             df_NTM.to_csv("TRUST_lowAF_NTM_read_counts.csv", index=False)
            
#     else:
#         print(f"Already finished {sample}")
        
# df_NTM.to_csv("TRUST_lowAF_NTM_read_counts.csv", index=False)
df_kraken_classified_reads = pd.read_csv("./kraken_full_DB_stats.csv")

# %%
df_kraken_classified_reads_with_patient_outcomes = df_kraken_classified_reads.merge(df_trust_patients).merge(df_final_outcomes[['pid', 'event_type', 'event', 'date']])#.pid.nunique()
df_kraken_classified_reads_with_TCC = df_kraken_classified_reads.merge(df_trust_patients).merge(df_TCC.query("imp_num==0"))#.pid.nunique()

# %%
df_kraken_classified_reads_with_patient_outcomes.query("Lineage=='1'")
# Out:
#     SampleID  Total_Reads_after_fastp  Keep_Reads_Kraken_Standard_DB  \
# 370  MFS-520                  4948935                        4909220
#
#      Keep_Proportion_Kraken_Standard_DB  \
# 370                            0.991975
#
#      Unclassified_Proportion_Kraken_Custom_DB  NTM_Reads  NTM_Proportion  \
# 370                                    0.0042      23099        0.004667
#
#        pid Original_ID         SampleLib  ...  last_dots_date        F2  \
# 370  T0017    S0017-01  MFS-520_lib64072  ...             210  0.019246
#
#      Coll2014  Freschi2020  Lineage  Sampling_Week  Paired_Sample_Num  \
# 370     1.1.2        1.1.2        1              1                  1
#
#      event_type  event   date
# 370  tx_failure      1  180.0
#
# [1 rows x 7112 columns]

# %%
sns.ecdfplot(data=df_kraken_classified_reads_with_patient_outcomes.query("NTM_Proportion > 0.01"),
            x='NTM_Proportion',
            hue='event',
             log_scale=10
           )

sns.despine()
plt.show()

# %%
df_kraken_classified_reads_with_patient_outcomes.groupby('event')['NTM_Proportion'].mean()
# Out:
# event
# 0    0.007845
# 1    0.006558
# Name: NTM_Proportion, dtype: float64

# %%
sns.ecdfplot(data=df_kraken_classified_reads_with_TCC.query("NTM_Proportion > 0.01"),
            x='NTM_Proportion',
            hue='culture_convert_imputed',
             log_scale=10
           )

sns.despine()
plt.show()

# %%
df_kraken_classified_reads_with_TCC.groupby('culture_convert_imputed')['NTM_Proportion'].mean()
# Out:
# culture_convert_imputed
# 0    0.007322
# 1    0.007954
# Name: NTM_Proportion, dtype: float64

# %%
sns.ecdfplot(data=df_kraken_classified_reads_with_patient_outcomes.query("NTM_Proportion > 0.01"),
            x='NTM_Proportion',
            hue='HIV_CD4',
             log_scale=10
           )

sns.despine()
plt.show()

# %%
st.spearmanr(df_kraken_classified_reads_with_TCC['NTM_Proportion'],
             df_kraken_classified_reads_with_TCC['TCC_imputed']
            )
# Out:
# SignificanceResult(statistic=-0.006597945294890712, pvalue=0.860686899978537)

# %% [markdown]
# # Analysis of Contaminants in Samples with Kraken Unclassified > 20%

# %%
df_TRUST_patients = pd.read_csv("/n/data1/hms/dbmi/farhat/rollingDB/TRUST/clinical_data/20241127_combined_patients_WGS_samples.csv")

# %%
df_TRUST = pd.read_csv("/n/data1/hms/dbmi/farhat/rollingDB/TRUST/Illumina_culture_WGS_summary.csv")

kraken_unclassified_samples = np.sort(df_TRUST.query("Kraken_Unclassified_Percent > 20").SampleID.values)
len(kraken_unclassified_samples)
# Out:
# 29

# %%
vcf_paths = pd.read_csv("/n/data1/hms/dbmi/farhat/Sanjana/MIC_data/TRUST/vcf_full_paths.txt", sep='\t', header=None)
len(vcf_paths)
# Out:
# 733

# %%
len(vcf_paths) + len(kraken_unclassified_samples) == len(df_TRUST)
# Out:
# True

# %%
vcf_samples = [os.path.basename(fName).split('.')[0] for fName in vcf_paths[0].values]

# %%
set(vcf_samples).symmetric_difference(df_TRUST.query("Kraken_Unclassified_Percent <= 20").SampleID)
# Out:
# set()

# %%
set(vcf_samples).intersection(kraken_unclassified_samples)
# Out:
# set()

# %%
df_TRUST.dropna(subset='Freschi2020').query("Freschi2020.str.contains(',')")
# Out:
#        pid SampleID  Kraken_Unclassified_Percent  Mean_Depth  Median_Depth  \
# 76   T0252  MFS-168                         1.35  382.326083         392.0
# 127  T0267  MFS-270                         0.57  298.796325         306.0
# 175  T0305  MFS-313                         0.91  322.862748         330.0
# 179  T0311  MFS-317                         0.69  379.240440         388.0
# 200  T0010  MFS-336                         0.34  337.337377         337.0
# 216  T0072  MFS-350                         0.42  344.440217         340.0
# 218  T0087  MFS-353                         0.36  419.230392         404.0
# 356  T0391  MFS-483                         0.40  265.043600         271.0
# 515  T0204  MFS-631                         0.59  269.194783         271.0
# 594  T0444  MFS-707                         0.49  454.523204         467.0
# 726  T0167   MFS-85                         0.80  361.552929         369.0
#
#      Perc_Sites_10x  Perc_Sites_20x        F2           Coll2014  \
# 76        99.426888       99.283786  0.477297    4.1.1.3,2.2.1.1
# 127       99.143381       98.926881  0.245979            2.2.1.1
# 175       99.098567       98.946783  0.436810    4.3.2.1,2.2.1.1
# 179       99.134677       98.974143  0.369685    4.3.2.1,2.2.1.1
# 200       99.275648       99.130982  0.458952    4.1.1.1,2.2.1.1
# 216       99.473584       99.345103  0.408194        4.1.2.1,4.8
# 218       99.482855       99.374435  0.415768        4.1.2.1,4.8
# 356       99.226595       99.070527  0.474464    4.1.1.3,2.2.1.1
# 515       99.395561       99.200096  0.314259        2.2.1,3.1.1
# 594       99.149071       99.043371  0.313857  4.3.4.2.1,4.1.1.1
# 726       99.372554       99.212133  0.259418      2.2.1,4.1.1.3
#
#                          Freschi2020 Lineage  Culture_Mixed_Infection  \
# 76              4.1.i1.2.1,2.2.1.1.1     2,4                        1
# 127         2.2.1.1.1,4.2.1.2.1.1.i1     2,4                        1
# 175         2.2.1.1.1,4.2.1.2.1.1.i1     2,4                        1
# 179         2.2.1.1.1,4.2.1.2.1.1.i1     2,4                        1
# 200             4.1.i1.2.1,2.2.1.1.1     2,4                        1
# 216  4.2.1.1.1.1.1.1.i1,4.1.i1.1.1.1       4                        1
# 218  4.2.1.1.1.1.1.1.i1,4.1.i1.1.1.1       4                        1
# 356             4.1.i1.2.1,2.2.1.1.1     2,4                        1
# 515               2.2.1.1.1,3.1.1.i1     2,3                        1
# 594        4.1.i1.2,4.2.1.2.1.1.i3.1       4                        1
# 726                    4.1,2.2.1.1.1     2,4                        1
#
#       Freschi_Lineage_1 Freschi_Lineage_2                       Lipworth2019  \
# 76           4.1.i1.2.1         2.2.1.1.1                      beijing,xtype
# 127           2.2.1.1.1    4.2.1.2.1.1.i1                  beijing,lam,mungi
# 175           2.2.1.1.1    4.2.1.2.1.1.i1                        beijing,lam
# 179           2.2.1.1.1    4.2.1.2.1.1.i1                        beijing,lam
# 200          4.1.i1.2.1         2.2.1.1.1         beijing,xtype,westafrican1
# 216  4.2.1.1.1.1.1.1.i1      4.1.i1.1.1.1                    haarlem,canetti
# 218  4.2.1.1.1.1.1.1.i1      4.1.i1.1.1.1                    haarlem,canetti
# 356          4.1.i1.2.1         2.2.1.1.1                      beijing,xtype
# 515           2.2.1.1.1          3.1.1.i1  beijing,east_african_indian,mungi
# 594            4.1.i1.2  4.2.1.2.1.1.i3.1             lam,xtype,westafrican1
# 726                 4.1         2.2.1.1.1                beijing,xtype,mungi
#
#                  Shitikov2017     Stucki2016
# 76     lin2.2.1,pacific_RD150            NaN
# 127    lin2.2.1,pacific_RD150            NaN
# 175    lin2.2.1,pacific_RD150        4.3/LAM
# 179    lin2.2.1,pacific_RD150        4.3/LAM
# 200    lin2.2.1,pacific_RD150            NaN
# 216                       NaN  4.1.2/Haarlem
# 218                       NaN  4.1.2/Haarlem
# 356    lin2.2.1,pacific_RD150            NaN
# 515                  lin2.2.1            NaN
# 594                       NaN        4.3/LAM
# 726  lin2.2.1,asian_african_2            NaN

# %%
df_report = pd.read_excel("/n/data1/hms/dbmi/farhat/rollingDB/TRUST/WGS_metadata_reports/2024-11-13_report.v10.xlsx", sheet_name=None)['summary']

# %%
df_report.SampleID.nunique(), df_TRUST.query("SampleID in @df_report.SampleID").SampleID.nunique()
# Out:
# (188, 163)

# %%
kraken_unclassified_samples
# Out:
# array(['MFS-179', 'MFS-183', 'MFS-304', 'MFS-422', 'MFS-423', 'MFS-425',
#        'MFS-451', 'MFS-453', 'MFS-477', 'MFS-490', 'MFS-491', 'MFS-492',
#        'MFS-493', 'MFS-494', 'MFS-495', 'MFS-496', 'MFS-497', 'MFS-498',
#        'MFS-499', 'MFS-500', 'MFS-501', 'MFS-502', 'MFS-503', 'MFS-504',
#        'MFS-505', 'MFS-506', 'MFS-507', 'MFS-508', 'MFS-78'], dtype=object)

# %%
bracken -d "/n/data1/hms/dbmi/farhat/mm774/References/Kraken2_DB_Dir/Kraken2_DB" -i /n/data1/hms/dbmi/farhat/rollingDB/TRUST/Illumina_culture_WGS_processed/MFS-179/MFS-179/kraken/kraken_report_standard_DB -o /n/data1/hms/dbmi/farhat/rollingDB/TRUST/Illumina_culture_WGS_processed/MFS-179/MFS-179/kraken/bracken_report -r 150 -l G1 -t 77643

# %%
df_TRUST_patients['status'].unique()
# Out:
# array([nan, 'finished', 'in progress', 'failed'], dtype=object)

# %%
failed_by_borstel = df_TRUST_patients.query("status=='failed'").SampleID.values
len(failed_by_borstel)
# Out:
# 16

# %%
og_missing_samples = df_TRUST_patients.loc[pd.isnull(df_TRUST_patients['Lineage'])].SampleID.values
len(og_missing_samples)
# Out:
# 54

# %%
kraken_contam_og_missing_samples = list(set(og_missing_samples).intersection(kraken_unclassified_samples))
len(kraken_contam_og_missing_samples)
# Out:
# 10

# %%
contamination_update.query("MFS_ID in @og_missing_samples & MFS_ID not in @kraken_unclassified_samples").shape
# Out:
# (44, 6)

# %%
contamination_update.query("MFS_ID in @og_missing_samples & MFS_ID not in @kraken_unclassified_samples").Class.value_counts()
# Out:
# Class
# Contam         22
# Outstanding    20
# Error           1
# Seq fail        1
# Name: count, dtype: int64

# %%
contamination_update.query("MFS_ID in @og_missing_samples").shape
# Out:
# (44, 6)

# %%
missing_samples = list(set(kraken_unclassified_samples) - set(df_TRUST_patients["SampleID"]))
len(missing_samples)
# Out:
# 19

# %%
df_report = pd.read_excel("/n/data1/hms/dbmi/farhat/rollingDB/TRUST/WGS_metadata_reports/2023-09-01_report_Farhat.v09.xlsx", sheet_name=None)

# %%
df_report['summary'].query("SampleID in @missing_samples").shape
# Out:
# (19, 11)

# %%
df_report['summary'].query("SampleID in @missing_samples")
# Out:
#     SampleID original ID shipment  status             comment  \
# 415  MFS-507         T-7      3rd  failed  Baym mit +5 Zyklen
# 416  MFS-505         T-5      3rd  failed  Baym mit +5 Zyklen
# 418  MFS-492      P-T- 1      3rd  failed  Baym mit +5 Zyklen
# 420  MFS-506         T-6      3rd  failed  Baym mit +5 Zyklen
# 422  MFS-500         C-8      3rd  failed  Baym mit +5 Zyklen
# 423  MFS-494         C-2      3rd  failed  Baym mit +5 Zyklen
# 425  MFS-495         C-3      3rd  failed  Baym mit +5 Zyklen
# 426  MFS-504         T-4      3rd  failed  Baym mit +5 Zyklen
# 427  MFS-499         C-7      3rd  failed  Baym mit +5 Zyklen
# 429  MFS-508         T-8      3rd  failed  Baym mit +5 Zyklen
# 430  MFS-503         T-3      3rd  failed  Baym mit +5 Zyklen
# 431  MFS-497         C-5      3rd  failed  Baym mit +5 Zyklen
# 432  MFS-502         T-2      3rd  failed  Baym mit +5 Zyklen
# 433  MFS-490       P-C-1      3rd  failed  Baym mit +5 Zyklen
# 434  MFS-496         C-4      3rd  failed  Baym mit +5 Zyklen
# 435  MFS-491       P-W-1      3rd  failed  Baym mit +5 Zyklen
# 436  MFS-498         C-6      3rd  failed  Baym mit +5 Zyklen
# 437  MFS-501         T-1      3rd  failed  Baym mit +5 Zyklen
# 438  MFS-493         C-1      3rd  failed  Baym mit +5 Zyklen
#
#             SampleLib phylogenetic classification (Coll et al., 2014)  \
# 415  MFS-507_lib59695                                     4.3.2.1 LAM
# 416  MFS-505_lib59693                   2.2.1.1 Beijing Pacific RD150
# 418  MFS-492_lib59680                                 2.2.1.1 Beijing
# 420  MFS-506_lib59694                                   2.2.1 Beijing
# 422  MFS-500_lib59688                   2.2.1.1 Beijing Pacific RD150
# 423  MFS-494_lib59682                                               -
# 425  MFS-495_lib59683                               4.4 Euro-American
# 426  MFS-504_lib59692                                     4.3.2.1 LAM
# 427  MFS-499_lib59687                        4.3.2 LAM Asian/Africa 1
# 429  MFS-508_lib59696                   2.2.1.1 Beijing Pacific RD150
# 430  MFS-503_lib59691                               4.4 Euro-American
# 431  MFS-497_lib59685                                 2.2.1.1 Beijing
# 432  MFS-502_lib59690                                    4.8 mainly T
# 433  MFS-490_lib59678                                 2.2.1.1 Beijing
# 434  MFS-496_lib59684                                               -
# 435  MFS-491_lib59679                               4.4 Euro-American
# 436  MFS-498_lib59686                                  4.1.1.3 X-type
# 437  MFS-501_lib59689                                               -
# 438  MFS-493_lib59681                                               -
#
#      quality  Cov Any Mean  Cov Unam Perc  Perc. Reads Mapped
# 415      1.0         52.12           0.99              0.4505
# 416      2.0         35.10           0.96              0.2683
# 418      4.0         17.81           0.88              0.1026
# 420      4.0         13.24           0.75              0.0965
# 422      4.0          9.19           0.49              0.0606
# 423      4.0          8.85           0.00              0.0024
# 425      4.0          7.95           0.00              0.0033
# 426      4.0          6.56           0.24              0.0644
# 427      4.0          5.72           0.19              0.0337
# 429      4.0          4.96           0.07              0.0331
# 430      4.0          4.66           0.00              0.0066
# 431      4.0          3.80           0.04              0.0253
# 432      4.0          3.00           0.00              0.0076
# 433      4.0          2.81           0.00              0.0094
# 434      4.0          2.81           0.00              0.0029
# 435      4.0          2.71           0.00              0.0099
# 436      4.0          2.17           0.00              0.0031
# 437      4.0          1.67           0.00              0.0004
# 438      4.0          1.24           0.00              0.0000

# %%
df_TRUST.query("SampleID=='MFS-270'")
# Out:
#        pid SampleID  Kraken_Unclassified_Percent  Mean_Depth  Median_Depth  \
# 127  T0267  MFS-270                         0.57  298.796325         306.0
#
#      Perc_Sites_10x  Perc_Sites_20x        F2 Coll2014  \
# 127       99.143381       98.926881  0.245979  2.2.1.1
#
#                   Freschi2020 Lineage  Culture_Mixed_Infection  \
# 127  2.2.1.1.1,4.2.1.2.1.1.i1     2,4                        1
#
#     Freschi_Lineage_1 Freschi_Lineage_2       Lipworth2019  \
# 127         2.2.1.1.1    4.2.1.2.1.1.i1  beijing,lam,mungi
#
#                Shitikov2017 Stucki2016
# 127  lin2.2.1,pacific_RD150        NaN

# %%
os.listdir("/n/data1/hms/dbmi/farhat/rollingDB/TRUST/WGS_metadata_reports")
# Out:
# ['2023-01-24_report_Farhat.v09.xlsx',
#  '2023-09-01_report_Farhat.v09.xlsx',
#  '2024-05-27_report.v10.xlsx',
#  '2024-06-25_report.v10.xlsx',
#  '2024-11-13_report.v10.xlsx']

# %%
kraken_unclassified_samples
# Out:
# array(['MFS-179', 'MFS-183', 'MFS-304', 'MFS-422', 'MFS-423', 'MFS-425',
#        'MFS-451', 'MFS-453', 'MFS-477', 'MFS-490', 'MFS-491', 'MFS-492',
#        'MFS-493', 'MFS-494', 'MFS-495', 'MFS-496', 'MFS-497', 'MFS-498',
#        'MFS-499', 'MFS-500', 'MFS-501', 'MFS-502', 'MFS-503', 'MFS-504',
#        'MFS-505', 'MFS-506', 'MFS-507', 'MFS-508', 'MFS-78'], dtype=object)

# %%
contamination_update = pd.read_excel("Contamination_Update_140124.xlsx", sheet_name=None)['Sheet1']

# %%
no_FQ = df_TRUST_patients.query("SampleID not in @df_TRUST.SampleID").SampleID.values

len(no_FQ)
# Out:
# 44

# %%
contamination_update.query("MFS_ID in @failed_by_borstel")
# Out:
#      MFS_ID   Isolate     Class                                   Status   \
# 9   MFS-376  S0165-05     Error      Labelling error sample doesn’t exist
# 10  MFS-378  S0198-06    Contam  Cultured and sequenced alternate isolate
# 11  MFS-379  S0199-05    Contam  Cultured and sequenced alternate isolate
# 12  MFS-380  S0211-09    Contam  Cultured and sequenced alternate isolate
# 13  MFS-384  S0272-06    Contam  Cultured and sequenced alternate isolate
# 14  MFS-386  S0282-01    Contam  Cultured and sequenced alternate isolate
# 23  MFS-352  S0073-01  Seq fail                  Recultured and sequenced
#
#     MFS_new Isolate_new
# 9       NaN         NaN
# 10  MFS-113    S0198-07
# 11  MFS-114    S0199-06
# 12  MFS-121    S0211-08
# 13  MFS-279    S0272-09
# 14  MFS-323    S0282-02
# 23  MFS-557    S0073-01

# %%
df_TRUST_patients.query("SampleID=='MFS-557'")
# Out:
#        pid Original_ID SampleID  specimen_time_point         SampleLib  \
# 279  T0073    S0073-01  MFS-557                  1.0  MFS-557_lib64397
#
#      Pacbio Comment  quality  Cov_Any_Mean  Cov_Unam_Perc  ...      fib4  \
# 279     NaN     NaN      1.0         259.8            1.0  ...  0.149688
#
#      prevtb_outcome  total_adherence  adherence_12week  first_dots_date  \
# 279             NaN            0.875              0.95                0
#
#      last_dots_date        F2 Coll2014 Freschi2020 Lineage
# 279             181  0.010704    3.1.1    3.1.1.i1       3
#
# [1 rows x 7102 columns]

# %%
borstel_contaminated = contamination_update.query("Class=='Contam'")['MFS_ID'].values
len(borstel_contaminated)
# Out:
# 22

# %%
# Out:
# (44, 6)

# %%
contamination_update.query("Class=='Outstanding'").shape
# Out:
# (20, 6)

# %%
contamination_update.dropna(subset='MFS_ID').MFS_ID.nunique()
# Out:
# 44

# %%
set(no_FQ).symmetric_difference(contamination_update.dropna(subset='MFS_ID').MFS_ID)
# Out:
# set()

# %%
contamination_update.query("MFS_ID in @kraken_unclassified_samples")
# Out:
# Empty DataFrame
# Columns: [MFS_ID, Isolate, Class, Status , MFS_new, Isolate_new]
# Index: []

# %%
contamination_update.dropna(subset='MFS_ID')
# Out:
#      MFS_ID   Isolate        Class  \
# 0   MFS-562  S0081-01       Contam
# 1   MFS-568  S0099-06       Contam
# 2   MFS-653  S0272-m5       Contam
# 3   MFS-712  S0450-01       Contam
# 4   MFS-749  S0157-01       Contam
# 5   MFS-775  S0382-01       Contam
# 6   MFS-810  S0428-01       Contam
# 7   MFS-827  S0447-04       Contam
# 8   MFS-785  S0402-04       Contam
# 9   MFS-376  S0165-05        Error
# 10  MFS-378  S0198-06       Contam
# 11  MFS-379  S0199-05       Contam
# 12  MFS-380  S0211-09       Contam
# 13  MFS-384  S0272-06       Contam
# 14  MFS-386  S0282-01       Contam
# 15  MFS-565  S0091-07       Contam
# 16  MFS-567  S0099-01       Contam
# 17  MFS-569  S0102-01       Contam
# 18  MFS-570  S0102-05       Contam
# 19  MFS-661  S0360-01       Contam
# 20  MFS-666  S0385-04       Contam
# 21  MFS-679  S0405-01       Contam
# 22  MFS-680  S0406-01       Contam
# 23  MFS-352  S0073-01     Seq fail
# 24  MFS-750  S0174-04  Outstanding
# 25  MFS-755  S0192-05  Outstanding
# 26  MFS-768  S0346-02  Outstanding
# 27  MFS-782  S0399-04  Outstanding
# 28  MFS-783  S0399-08  Outstanding
# 29  MFS-814  S0432-07  Outstanding
# 30  MFS-815  S0434-01  Outstanding
# 31  MFS-816  S0434-08  Outstanding
# 32  MFS-817  S0435-06  Outstanding
# 33  MFS-819  S0437-05  Outstanding
# 34  MFS-820  S0439-07  Outstanding
# 35  MFS-821  S0440-07  Outstanding
# 36  MFS-822  S0441-08  Outstanding
# 37  MFS-823  S0444-08  Outstanding
# 38  MFS-824  S0445-01  Outstanding
# 39  MFS-828  S0449-08  Outstanding
# 40  MFS-829  S0450-05  Outstanding
# 41  MFS-830  S0451-05  Outstanding
# 42  MFS-838  S0458-08  Outstanding
# 43  MFS-844  S0462-01  Outstanding
#
#                                               Status   MFS_new Isolate_new
# 0                                         Reculturing      NaN         NaN
# 1                                         Reculturing      NaN         NaN
# 2                                         Reculturing      NaN         NaN
# 3                                         Reculturing      NaN         NaN
# 4                                         Reculturing      NaN         NaN
# 5                                         Reculturing      NaN         NaN
# 6                                         Reculturing      NaN         NaN
# 7                                         Reculturing      NaN         NaN
# 8                                         Reculturing      NaN         NaN
# 9                Labelling error sample doesn’t exist      NaN         NaN
# 10           Cultured and sequenced alternate isolate  MFS-113    S0198-07
# 11           Cultured and sequenced alternate isolate  MFS-114    S0199-06
# 12           Cultured and sequenced alternate isolate  MFS-121    S0211-08
# 13           Cultured and sequenced alternate isolate  MFS-279    S0272-09
# 14           Cultured and sequenced alternate isolate  MFS-323    S0282-02
# 15           Cultured and sequenced alternate isolate  MFS-736    S0091-05
# 16             Recultured on selectatab and sequenced  MFS-738    S0099-01
# 17             Recultured on selectatab and sequenced  MFS-739    S0102-01
# 18             Recultured on selectatab and sequenced  MFS-740    S0102-05
# 19             Recultured on selectatab and sequenced  MFS-770    S0360-01
# 20             Recultured on selectatab and sequenced  MFS-778    S0385-04
# 21             Recultured on selectatab and sequenced  MFS-787    S0405-01
# 22             Recultured on selectatab and sequenced  MFS-789    S0406-02
# 23                           Recultured and sequenced  MFS-557    S0073-01
# 24  No contam detected (Borstel) but still sequenc...      NaN         NaN
# 25  No contam detected (Borstel) but still sequenc...      NaN         NaN
# 26  No contam detected (Borstel) but still sequenc...      NaN         NaN
# 27  No contam detected (Borstel) but still sequenc...      NaN         NaN
# 28  No contam detected (Borstel) but still sequenc...      NaN         NaN
# 29  No contam detected (Borstel) but still sequenc...      NaN         NaN
# 30  No contam detected (Borstel) but still sequenc...      NaN         NaN
# 31  No contam detected (Borstel) but still sequenc...      NaN         NaN
# 32  No contam detected (Borstel) but still sequenc...      NaN         NaN
# 33  No contam detected (Borstel) but still sequenc...      NaN         NaN
# 34  No contam detected (Borstel) but still sequenc...      NaN         NaN
# 35  No contam detected (Borstel) but still sequenc...      NaN         NaN
# 36  No contam detected (Borstel) but still sequenc...      NaN         NaN
# 37  No contam detected (Borstel) but still sequenc...      NaN         NaN
# 38  No contam detected (Borstel) but still sequenc...      NaN         NaN
# 39  No contam detected (Borstel) but still sequenc...      NaN         NaN
# 40  No contam detected (Borstel) but still sequenc...      NaN         NaN
# 41  No contam detected (Borstel) but still sequenc...      NaN         NaN
# 42  No contam detected (Borstel) but still sequenc...      NaN         NaN
# 43  No contam detected (Borstel) but still sequenc...      NaN         NaN

# %%
pd.DataFrame({'A': kraken_unclassified_samples, 'B': kraken_unclassified_samples, 'C': 0}).iloc[:, :].to_csv("/home/sak0914/Mtb_Megapipe/TRUST_samples.tsv", index=False, sep='\t', header=None)

# %%
kraken_unclassified_samples
# Out:
# array(['MFS-179', 'MFS-183', 'MFS-304', 'MFS-422', 'MFS-423', 'MFS-425',
#        'MFS-451', 'MFS-453', 'MFS-477', 'MFS-490', 'MFS-491', 'MFS-492',
#        'MFS-493', 'MFS-494', 'MFS-495', 'MFS-496', 'MFS-497', 'MFS-498',
#        'MFS-499', 'MFS-500', 'MFS-501', 'MFS-502', 'MFS-503', 'MFS-504',
#        'MFS-505', 'MFS-506', 'MFS-507', 'MFS-508', 'MFS-78'], dtype=object)

# %%
df_kraken_contaminants = pd.DataFrame(columns = ['SampleID', 'Custom_DB_MTBC_percent', 'non_MTBC_mycobacteria', 'unclassified_percent', 'MTBC_percent', 'NTM_percent', 'NTM_mycobacteria_percent', 'Human_percent', 'Most_Common_Genus', 'Most_Common_Genus_percent', 'Second_Most_Common_Genus', 'Second_Most_Common_Genus_percent'])#, 'Most_Common_Species'])

for i, sample in enumerate(kraken_unclassified_samples):

    fName = f"{genomic_data_dir}/{sample}/{sample}/kraken/kraken_report_standard_DB"

    if os.path.isfile(fName):

        df_kraken_custom_DB = pd.read_csv(f"{genomic_data_dir}/{sample}/{sample}/kraken/kraken_report", sep='\t', header=None)
        df_kraken_custom_DB.columns = ['Percent', 'Cumul_Count', 'Count', 'TaxLevel', 'TaxID', 'TaxName']

        kraken_custom_DB_MTBC_percent = 100 - df_kraken_custom_DB.query("TaxLevel=='U'")['Percent'].values[0]

        df_kraken_standard_DB = pd.read_csv(fName, sep='\t', header=None)
        df_kraken_standard_DB.columns = ['Percent', 'Cumul_Count', 'Count', 'TaxLevel', 'TaxID', 'TaxName']

        non_MTBC_mycobacteria = df_kraken_standard_DB.query("TaxID in @mycobacterium_child_taxids & TaxID not in @MTBC_child_taxids & TaxLevel == 'S'")['Percent'].sum()

        unclassified_percent = df_kraken_standard_DB.query("TaxLevel=='U'")['Percent'].values[0]

        MTBC_percent = df_kraken_standard_DB.query("TaxID==77643")['Percent'].values[0]
        
        try:
            # M. leprosy is in the genus Mycobacterium. NTM = all Mycobacteria that are not MTBC or M. leprae BUT some NTMs have been split into other genera, so also need to include those
            M_leprae_percent = df_kraken_standard_DB.query("TaxName.str.contains('leprae') & TaxLevel=='S'")['Percent'].sum()
        except:
            M_leprae_percent = 0

        human_percent = df_kraken_standard_DB.query("TaxName.str.contains('Homo sapiens')")['Percent'].values[0]

        try:
            # this is a G1 level
            unclassified_mycobacterium_percent = df_kraken_standard_DB.query("TaxName.str.contains('unclassified Mycobacterium')")['Percent'].values[0]
        except:
            unclassified_mycobacterium_percent = 0

        # Mycobacterium is the genus level. MTBC, M. avium complex, etc. are all G1 level
        mycobacterium_percent = df_kraken_standard_DB.query("TaxID==1763")['Percent'].values[0]

        # NTMs were recently split into some other genera: Mycobacteroides, Mycolicibacter, Mycolicibacterium and Mycolicibacillus
        other_NTM_genera_percent = df_kraken_standard_DB.query("TaxLevel=='G' & TaxName.str.contains('|'.join(['Mycobacteroides', 'Mycolicibacter', 'Mycolicibacterium', 'Mycolicibacillus']))")['Percent'].sum()

        # NTMs will be full mycobacterium - MTBC - M. leprae - unclassified mycobacterium + other NTM genera
        # full mycobacterium = G
        # MTBC, unclassified mycobacterium = G1
        # M. leprae is just a G and S
        NTM_mycobacteria_percent = mycobacterium_percent - MTBC_percent - M_leprae_percent - unclassified_mycobacterium_percent
        NTM_percent = mycobacterium_percent - MTBC_percent - M_leprae_percent - unclassified_mycobacterium_percent + other_NTM_genera_percent

        # get the most common contaminating genus and species. Remove spaces for ease
        most_common_genus = df_kraken_standard_DB.query("TaxLevel=='G'").sort_values('Percent', ascending=False)['TaxName'].str.lstrip().values[0]
        second_most_common_genus = df_kraken_standard_DB.query("TaxLevel=='G'").sort_values('Percent', ascending=False)['TaxName'].str.lstrip().values[1]
        # most_common_species = df_kraken_standard_DB.query("TaxLevel=='S'").sort_values('Percent', ascending=False)['TaxName'].str.lstrip().values[0]

        most_common_genus_percent = df_kraken_standard_DB.query("TaxLevel=='G'")['Percent'].values.max()
        second_most_common_genus_percent = df_kraken_standard_DB.query("TaxLevel=='G'").sort_values('Percent', ascending=False)['Percent'].values[1]
        
        df_kraken_contaminants.loc[i, :] = [sample, kraken_custom_DB_MTBC_percent, non_MTBC_mycobacteria, unclassified_percent, MTBC_percent, NTM_percent, NTM_mycobacteria_percent, human_percent, most_common_genus, most_common_genus_percent, second_most_common_genus, second_most_common_genus_percent]#, most_common_species]

    else:
        print(sample)


df_kraken_contaminants[['SampleID', 'unclassified_percent', 'MTBC_percent', 'NTM_percent', 'Human_percent', 'Most_Common_Genus', 'Most_Common_Genus_percent', 'Second_Most_Common_Genus', 'Second_Most_Common_Genus_percent']].sort_values("SampleID").to_csv("Kraken_Contamination_analysis.csv", index=False)
# df_kraken_contaminants['Sum_Percent'] = df_kraken_contaminants[df_kraken_contaminants.columns[df_kraken_contaminants.columns.str.contains('percent')]].sum(axis=1).values

# %%
sns.scatterplot(data=df_kraken_contaminants,
                x='NTM_percent',
                y='Custom_DB_MTBC_percent'
               )
# Out:
# <Axes: xlabel='NTM_percent', ylabel='Custom_DB_MTBC_percent'>

# %%
df_kraken_contaminants.query("Custom_DB_MTBC_percent < NTM_percent")
# Out:
#    SampleID Custom_DB_MTBC_percent non_MTBC_mycobacteria unclassified_percent  \
# 0   MFS-179                   4.61                  2.53                 7.33
# 1   MFS-183                  54.94                 33.78                 6.41
# 3   MFS-422                  22.65                 81.96                 1.13
# 5   MFS-425                  14.77                 90.17                 1.29
# 6   MFS-451                  12.55                 67.85                11.37
# 8   MFS-477                   2.15                  1.61                52.08
# 28   MFS-78                  36.58                 57.83                 6.71
#
#    MTBC_percent NTM_percent NTM_mycobacteria_percent Human_percent  \
# 0          0.05       90.22                     2.79          0.44
# 1          9.93       80.02                    78.74          0.66
# 3          2.59       94.74                     94.4          0.31
# 5          0.71       96.32                    95.94          0.31
# 6           0.6       82.68                    80.29          0.32
# 8           0.2        6.44                     2.26           0.3
# 28         5.63       85.68                    84.96          0.28
#
#     Most_Common_Genus Most_Common_Genus_percent Second_Most_Common_Genus  \
# 0   Mycolicibacterium                     87.19            Mycobacterium
# 1       Mycobacterium                     89.63        Mycolicibacterium
# 3       Mycobacterium                     97.35                     Homo
# 5       Mycobacterium                     97.03                     Homo
# 6       Mycobacterium                     82.71        Mycolicibacterium
# 8            Gordonia                     19.54        Mycolicibacterium
# 28      Mycobacterium                     91.09        Mycolicibacterium
#
#    Second_Most_Common_Genus_percent
# 0                               3.3
# 1                              1.14
# 3                              0.31
# 5                              0.31
# 6                              2.14
# 8                              3.63
# 28                             0.64

# %%
df_kraken_contaminants.query("NTM_percent > 70")
# Out:
#    SampleID Custom_DB_MTBC_percent non_MTBC_mycobacteria unclassified_percent  \
# 0   MFS-179                   4.61                  2.53                 7.33
# 1   MFS-183                  54.94                 33.78                 6.41
# 3   MFS-422                  22.65                 81.96                 1.13
# 5   MFS-425                  14.77                 90.17                 1.29
# 6   MFS-451                  12.55                 67.85                11.37
# 28   MFS-78                  36.58                 57.83                 6.71
#
#    MTBC_percent NTM_percent NTM_mycobacteria_percent Human_percent  \
# 0          0.05       90.22                     2.79          0.44
# 1          9.93       80.02                    78.74          0.66
# 3          2.59       94.74                     94.4          0.31
# 5          0.71       96.32                    95.94          0.31
# 6           0.6       82.68                    80.29          0.32
# 28         5.63       85.68                    84.96          0.28
#
#     Most_Common_Genus Most_Common_Genus_percent Second_Most_Common_Genus  \
# 0   Mycolicibacterium                     87.19            Mycobacterium
# 1       Mycobacterium                     89.63        Mycolicibacterium
# 3       Mycobacterium                     97.35                     Homo
# 5       Mycobacterium                     97.03                     Homo
# 6       Mycobacterium                     82.71        Mycolicibacterium
# 28      Mycobacterium                     91.09        Mycolicibacterium
#
#    Second_Most_Common_Genus_percent
# 0                               3.3
# 1                              1.14
# 3                              0.31
# 5                              0.31
# 6                              2.14
# 28                             0.64

# %%
df_kraken_standard_DB.query("TaxName.str.contains('unclassified Mycobacterium')")
# Out:
#      Percent  Cumul_Count  Count TaxLevel    TaxID  \
# 188     0.36        21832   2560       G1  2642494
#
#                                           TaxName
# 188                    unclassified Mycobacterium

# %%
df_kraken_standard_DB.query("TaxID==1763")
# Out:
#    Percent  Cumul_Count    Count TaxLevel  TaxID  \
# 9    91.09      5465215  1506977        G   1763
#
#                          TaxName
# 9                  Mycobacterium

# %%
df_kraken_standard_DB.query("TaxID in @mycobacterium_child_taxids & TaxLevel != 'G'")
# Out:
#      Percent  Cumul_Count    Count TaxLevel    TaxID  \
# 10     55.54      3331901   138176       G1   120793
# 11     37.99      2279317        0        S   339268
# 12     37.99      2279317  2279317       S1  1041522
# 13     10.40       623690   623690        S   560555
# 14      2.21       132705   132705        S   701042
# ..       ...          ...      ...      ...      ...
# 225     0.00           42       42       S1  1124626
# 226     0.00          105        0        S   261524
# 227     0.00          105      105       S1   459424
# 228     0.00           25        0        S   265949
# 229     0.00           25       25       S1  1136880
#
#                                                TaxName
# 10                     Mycobacterium avium complex ...
# 11                           Mycobacterium colombiense
# 12                         Mycobacterium colombiens...
# 13                              Mycobacterium mantenii
# 14                          Mycobacterium marseillense
# ..                                                 ...
# 225                      Mycobacterium ulcerans sub...
# 226                            Mycobacterium liflandii
# 227                      Mycobacterium liflandii 12...
# 228                       Mycobacterium pseudoshottsii
# 229                      Mycobacterium pseudoshotts...
#
# [218 rows x 6 columns]

# %%
df_kraken_standard_DB.query("TaxID in @mycobacterium_child_taxids & TaxLevel=='G1'")
# Out:
#      Percent  Cumul_Count   Count TaxLevel    TaxID  \
# 10     55.54      3331901  138176       G1   120793
# 31      5.63       337931  165744       G1    77643
# 179     2.38       143037    8089       G1  2249310
# 188     0.36        21832    2560       G1  2642494
#
#                                                TaxName
# 10                     Mycobacterium avium complex ...
# 31                     Mycobacterium tuberculosis c...
# 179                       Mycobacterium simiae complex
# 188                         unclassified Mycobacterium

# %%
df_kraken_standard_DB.query("TaxName.str.contains('unclassified Mycobacterium')")
# Out:
#      Percent  Cumul_Count  Count TaxLevel    TaxID  \
# 188     0.36        21832   2560       G1  2642494
#
#                                           TaxName
# 188                    unclassified Mycobacterium

# %%
df_kraken_contaminants.sort_values("MTBC_percent", ascending=False).head(5)
# Out:
#    SampleID Custom_DB_MTBC_percent non_MTBC_mycobacteria unclassified_percent  \
# 4   MFS-423                  60.32                  0.44                 2.11
# 1   MFS-183                  54.94                 33.78                 6.41
# 2   MFS-304                   47.5                  0.42                 1.68
# 26  MFS-507                  56.99                  0.44                 1.89
# 28   MFS-78                  36.58                 57.83                 6.71
#
#    MTBC_percent NTM_percent Human_percent Most_Common_Genus  \
# 4         11.94       48.12          0.21     Mycobacterium
# 1          9.93       80.02          0.66     Mycobacterium
# 2          9.72       37.57          0.37    Staphylococcus
# 26         8.11       48.84         35.22     Mycobacterium
# 28         5.63       85.68          0.28     Mycobacterium
#
#    Most_Common_Genus_percent Second_Most_Common_Genus  \
# 4                       60.1        Propionibacterium
# 1                      89.63        Mycolicibacterium
# 2                      50.24            Mycobacterium
# 26                     56.99                     Homo
# 28                     91.09        Mycolicibacterium
#
#    Second_Most_Common_Genus_percent
# 4                             36.59
# 1                              1.14
# 2                             47.34
# 26                            35.22
# 28                             0.64

# %%
df_kraken_contaminants['MTBC_NTM_sum_percent'] = df_kraken_contaminants['MTBC_percent'] + df_kraken_contaminants['NTM_percent']

# %%
df_kraken_contaminants.query("Most_Common_Genus=='Mycobacterium'")[['SampleID', 'Custom_DB_MTBC_percent', 'non_MTBC_mycobacteria', 'MTBC_percent', 'NTM_percent', 'MTBC_NTM_sum_percent', 'Most_Common_Genus', 'Most_Common_Genus_percent']]
# Out:
#    SampleID Custom_DB_MTBC_percent non_MTBC_mycobacteria MTBC_percent  \
# 1   MFS-183                  54.94                 33.78         9.93
# 3   MFS-422                  22.65                 81.96         2.59
# 4   MFS-423                  60.32                  0.44        11.94
# 5   MFS-425                  14.77                 90.17         0.71
# 6   MFS-451                  12.55                 67.85          0.6
# 26  MFS-507                  56.99                  0.44         8.11
# 28   MFS-78                  36.58                 57.83         5.63
#
#    NTM_percent MTBC_NTM_sum_percent Most_Common_Genus  \
# 1        80.02                89.95     Mycobacterium
# 3        94.74                97.33     Mycobacterium
# 4        48.12                60.06     Mycobacterium
# 5        96.32                97.03     Mycobacterium
# 6        82.68                83.28     Mycobacterium
# 26       48.84                56.95     Mycobacterium
# 28       85.68                91.31     Mycobacterium
#
#    Most_Common_Genus_percent
# 1                      89.63
# 3                      97.35
# 4                       60.1
# 5                      97.03
# 6                      82.71
# 26                     56.99
# 28                     91.09

# %%
sample = 'MFS-422'
fName = f"{genomic_data_dir}/{sample}/{sample}/kraken/kraken_report_standard_DB"
df_kraken_standard_DB = pd.read_csv(fName, sep='\t', header=None)
df_kraken_standard_DB.columns = ['Percent', 'Cumul_Count', 'Count', 'TaxLevel', 'TaxID', 'TaxName']

df_kraken_custom_DB = pd.read_csv(f"{genomic_data_dir}/{sample}/{sample}/kraken/kraken_report", sep='\t', header=None)
df_kraken_custom_DB.columns = ['Percent', 'Cumul_Count', 'Count', 'TaxLevel', 'TaxID', 'TaxName']

# %%
df_kraken_standard_DB.query("TaxID in @child_taxids").TaxLevel.unique()
# Out:
# array(['G1', 'S', 'S1', 'S2', 'S3'], dtype=object)

# %%
df_kraken_standard_DB.query("TaxID in @MTBC_child_taxids & TaxLevel != 'G1'")['Percent'].sum()
# Out:
# 1.56

# %%
df_kraken_standard_DB.query("TaxID in @mycobacterium_child_taxids & TaxLevel != 'G' & TaxID not in @MTBC_child_taxids")['Percent'].sum()
# Out:
# 184.34000000000003

# %%
df_kraken_standard_DB.query("TaxID in @mycobacterium_child_taxids & TaxLevel != 'G' & TaxID not in @MTBC_child_taxids").TaxLevel.unique()
# Out:
# array(['G1', 'S', 'S1', 'S2'], dtype=object)

# %%
# Out:
#      Percent  Cumul_Count    Count TaxLevel    TaxID  \
# 11     80.68      4090732  3166272        S     1764
# 19      0.24        12231    12231        S    64667
# 20      0.20        10009     8526        S     1767
# 27      0.03         1681     1681        S   560555
# 28      0.02         1169        0        S   339268
# 30      0.02          978      978        S  1138383
# 31      0.02          941      941        S   701042
# 32      0.01          439      439        S   222805
# 176     0.36        18281    18281        S    44010
# 178     0.03         1627     1627        S  2675523
# 180     0.02          858      858        S   212767
# 181     0.01          423      423        S  1561223
# 182     0.00          172      172        S  1936029
# 183     0.00          130      130        S  2675524
# 184     0.00           83       83        S   189918
# 185     0.00           78       78        S  2051552
# 186     0.00           72       72        S  2041046
# 187     0.00           59       59        S  1545728
# 188     0.00           56       56        S  1547487
# 189     0.00           51       51        S  2587868
# 190     0.00           41       41        S  1682113
# 191     0.00           21       21        S  1920667
# 192     0.00            3        3        S  1168287
# 194     0.04         1859     1859        S   185642
# 195     0.01          588      588        S    53376
# 196     0.01          469      469        S   220927
# 197     0.01          412      412        S   292462
# 198     0.01          296      296        S   470076
# 199     0.01          290      290        S   722731
# 200     0.00          252      252        S     1784
# 201     0.05         2785     2785        S   386911
# 202     0.04         2104     2104        S   590652
# 203     0.04         1958     1958        S   169765
# 204     0.02          920      920        S   398694
# 205     0.02          912      912        S     1789
# 206     0.01          658      658        S    43348
# 207     0.01          549      533        S     1781
# 210     0.01          390      390        S     1768
# 211     0.01          319      319        S  1389713
# 212     0.01          316        0        S    29311
# 215     0.01          268      268        S  2094119
# 216     0.00          227      227        S   459858
# 217     0.00          205      205        S     1775
# 218     0.00          129      129        S   482462
# 219     0.00           70       70        S     1769
# 220     0.00           56       56        S    39689
# 221     0.00           24       10        S     1809
# 223     0.00            8        0        S   261524
# 225     0.00            2        0        S   265949
#
#                                                TaxName
# 11                                 Mycobacterium avium
# 19                          Mycobacterium lepraemurium
# 20                        Mycobacterium intracellulare
# 27                              Mycobacterium mantenii
# 28                           Mycobacterium colombiense
# 30                       Mycobacterium paraintracel...
# 31                          Mycobacterium marseillense
# 32                              Mycobacterium chimaera
# 176                           Mycobacterium conspicuum
# 178                            Mycobacterium sp. DL440
# 180                            Mycobacterium sp. JS623
# 181                           Mycobacterium sp. QIA-37
# 182                           Mycobacterium sp. MS1601
# 183                            Mycobacterium sp. DL592
# 184                              Mycobacterium sp. KMS
# 185                            Mycobacterium sp. PYR15
# 186                           Mycobacterium sp. 3/86Rv
# 187                            Mycobacterium sp. EPa45
# 188                             Mycobacterium sp. ELW1
# 189                          Mycobacterium sp. THAF192
# 190                           Mycobacterium sp. YC-RL4
# 191                             Mycobacterium sp. WY10
# 192                          Mycobacterium sp. MOTT36Y
# 194                             Mycobacterium parmense
# 195                       Mycobacterium heidelbergense
# 196                      Mycobacterium saskatchewan...
# 197                          Mycobacterium florentinum
# 198                          Mycobacterium stomatepiae
# 199                            Mycobacterium shigaense
# 200                               Mycobacterium simiae
# 201                            Mycobacterium seoulense
# 202                        Mycobacterium paraseoulense
# 203                                Mycobacterium lacus
# 204                         Mycobacterium shinjukuense
# 205                               Mycobacterium xenopi
# 206                             Mycobacterium branderi
# 207                              Mycobacterium marinum
# 210                             Mycobacterium kansasii
# 211                         Mycobacterium paragordonae
# 212                          Mycobacterium haemophilum
# 215                           Mycobacterium basiliense
# 216                         Mycobacterium noviomagense
# 217                               Mycobacterium cookii
# 218                     Mycobacterium dioxanotrophicus
# 219                               Mycobacterium leprae
# 220                           Mycobacterium gallinarum
# 221                             Mycobacterium ulcerans
# 223                            Mycobacterium liflandii
# 225                       Mycobacterium pseudoshottsii

# %%
# def get_child_taxids(parent_taxid):
#     Entrez.email = "skulkarni@g.harvard.edu"  # Replace with your email

#     # Search for child taxids
#     max_results = 10000
    
#     search_handle = Entrez.esearch(db="taxonomy", term=f"txid{parent_taxid}[Subtree]", retmax=max_results)
#     search_results = Entrez.read(search_handle)
#     search_handle.close()

#     # Fetch details for the found taxids
#     id_list = search_results["IdList"]
#     if not id_list:
#         return []

#     fetch_handle = Entrez.efetch(db="taxonomy", id=",".join(id_list), retmode="xml")
#     fetch_results = Entrez.read(fetch_handle)
#     fetch_handle.close()

#     # Extract the taxids
#     child_taxids = [taxon["TaxId"] for taxon in fetch_results]

#     if len(child_taxids) == max_results:
#         raise ValueError(f"Please raise the max_results variable. {max_results} results were found!")

#     return np.array(child_taxids).astype(int)

# Example usage
parent_taxid = 77643
MTBC_child_taxids = get_child_taxids(parent_taxid)
# print(f"{len(child_taxids)} taxids of {parent_taxid}")

parent_taxid = 1763
mycobacterium_child_taxids = get_child_taxids(parent_taxid)

# %%
len(MTBC_child_taxids), len(mycobacterium_child_taxids)
# Out:
# (3061, 6670)

# %%
df_kraken_standard_DB.query("TaxName.str.contains('Mycobacterium') & TaxLevel=='G1'")
# Out:
#      Percent  Cumul_Count   Count TaxLevel    TaxID  \
# 10     55.54      3331901  138176       G1   120793
# 31      5.63       337931  165744       G1    77643
# 179     2.38       143037    8089       G1  2249310
# 188     0.36        21832    2560       G1  2642494
#
#                                                TaxName
# 10                     Mycobacterium avium complex ...
# 31                     Mycobacterium tuberculosis c...
# 179                       Mycobacterium simiae complex
# 188                         unclassified Mycobacterium

# %%
df_kraken_standard_DB.query("TaxName.str.contains('unclassified Mycobacterium')")
# Out:
#      Percent  Cumul_Count  Count TaxLevel    TaxID  \
# 188     0.36        21832   2560       G1  2642494
#
#                                           TaxName
# 188                    unclassified Mycobacterium

# %%
df_kraken_standard_DB.query("TaxLevel=='S'")['Percent'].sum()
# Out:
# 61.71000000000001

# %%
df_kraken_custom_DB.query("TaxLevel=='U'")
# Out:
#    Percent  Cumul_Count    Count TaxLevel  TaxID       TaxName
# 0    63.42      3804670  3804670        U      0  unclassified

# %%
df_kraken_custom_DB
# Out:
#     Percent  Cumul_Count    Count TaxLevel    TaxID  \
# 0     63.42      3804670  3804670        U        0
# 1     36.58      2194920        0        R        1
# 2     36.58      2194920        0       R1   131567
# 3     36.58      2194920        0        D        2
# 4     36.58      2194920        0       D1  1783272
# 5     36.58      2194920        0        P   201174
# 6     36.58      2194920        0        C     1760
# 7     36.58      2194920        0        O    85007
# 8     36.58      2194920        0        F     1762
# 9     36.58      2194920        0        G     1763
# 10    36.58      2194920        0       G1    77643
# 11    36.58      2194920  2193423        S     1773
# 12     0.01          774      774       S1    83331
# 13     0.00          282      282       S1   336982
# 14     0.00          221      221       S1    83332
# 15     0.00          220      220       S1   707235
#
#                                               TaxName
# 0                                        unclassified
# 1                                                root
# 2                                  cellular organisms
# 3                                            Bacteria
# 4                                 Terrabacteria group
# 5                                      Actinomycetota
# 6                                       Actinomycetes
# 7                                     Mycobacteriales
# 8                                    Mycobacteriaceae
# 9                                       Mycobacterium
# 10                    Mycobacterium tuberculosis c...
# 11                         Mycobacterium tuberculosis
# 12                        Mycobacterium tuberculos...
# 13                        Mycobacterium tuberculos...
# 14                        Mycobacterium tuberculos...
# 15                        Mycobacterium tuberculos...

# %%
df_kraken_contaminants.query("SampleID=='MFS-78'")#.sort_values("unclassified_percent")
# Out:
#    SampleID Custom_DB_MTBC_percent unclassified_percent MTBC_percent  \
# 28   MFS-78                  36.58                 6.71         5.63
#
#    NTM_percent Human_percent Most_Common_Genus Most_Common_Genus_percent  \
# 28       85.68          0.28     Mycobacterium                     91.09
#
#    Second_Most_Common_Genus Second_Most_Common_Genus_percent
# 28        Mycolicibacterium                             0.64

# %%
df_kraken_contaminants[['SampleID', 'Custom_DB_MTBC_percent', 'MTBC_percent']]
# Out:
#    SampleID Custom_DB_MTBC_percent MTBC_percent
# 0   MFS-179                   4.61         0.05
# 1   MFS-183                  54.94         9.93
# 2   MFS-304                   47.5         9.72
# 3   MFS-422                  22.65         2.59
# 4   MFS-423                  60.32        11.94
# 5   MFS-425                  14.77         0.71
# 6   MFS-451                  12.55          0.6
# 7   MFS-453                   3.49         0.39
# 8   MFS-477                   2.15          0.2
# 9   MFS-490                   0.75         0.06
# 10  MFS-491                   0.81         0.07
# 11  MFS-492                  12.31         2.18
# 12  MFS-493                    0.0          0.0
# 13  MFS-494                   0.33          0.0
# 14  MFS-495                   0.46          0.0
# 15  MFS-496                   0.28         0.02
# 16  MFS-497                   2.84         0.42
# 17  MFS-498                   0.25         0.02
# 18  MFS-499                   3.58         0.46
# 19  MFS-500                   6.97          0.9
# 20  MFS-501                   0.01          0.0
# 21  MFS-502                   1.08         0.07
# 22  MFS-503                   1.21         0.02
# 23  MFS-504                  18.59          2.9
# 24  MFS-505                  29.97          4.7
# 25  MFS-506                  11.08         1.74
# 26  MFS-507                  56.99         8.11
# 27  MFS-508                   4.07         0.66
# 28   MFS-78                  36.58         5.63

# %%
sns.scatterplot(data=df_kraken_contaminants,
                x='MTBC_percent',
                y='Custom_DB_MTBC_percent'
               )
# Out:
# <Axes: xlabel='MTBC_percent', ylabel='Custom_DB_MTBC_percent'>

# %%
st.spearmanr(df_kraken_contaminants['MTBC_percent'], df_kraken_contaminants['Custom_DB_MTBC_percent'])
# Out:
# SignificanceResult(statistic=0.9552144674515218, pvalue=8.359773985747886e-16)

# %%
st.pearsonr(df_kraken_contaminants['MTBC_percent'], df_kraken_contaminants['Custom_DB_MTBC_percent'])
# Out:
# PearsonRResult(statistic=0.9774808950585164, pvalue=8.879537894008935e-20)

# %%
df_trust_patients.query("SampleID=='MFS-78'")
# Out:
#       pid Original_ID SampleID  specimen_time_point        SampleLib  Pacbio  \
# 46  T0157      157-01   MFS-78                  1.0  MFS-78_lib47065     NaN
#
#    Comment  quality  Cov_Any_Mean  Cov_Unam_Perc  ...      fib4  \
# 46     NaN      3.0        147.41            0.7  ...  1.237429
#
#     prevtb_outcome  total_adherence  adherence_12week  first_dots_date  \
# 46             3.0         0.918033          0.881356                4
#
#     last_dots_date  F2 Coll2014 Freschi2020 Lineage
# 46             179 NaN      NaN         NaN     NaN
#
# [1 rows x 7102 columns]

# %%
df_kraken_standard_DB.query("TaxName.str.contains('Mycobacterium tuberculosis complex')")
# Out:
#     Percent  Cumul_Count   Count TaxLevel  TaxID  \
# 31     5.63       337931  165744       G1  77643
#
#                                               TaxName
# 31                    Mycobacterium tuberculosis c...

# %%
df_kraken_standard_DB.query("TaxLevel=='G' & TaxName.str.contains('|'.join(['Mycobacteroides', 'Mycolicibacter', 'Mycolicibacterium', 'Mycolicibacillus']))")
# Out:
#      Percent  Cumul_Count  Count TaxLevel    TaxID  \
# 230     0.64        38316   3256        G  1866885
# 281     0.05         3298     56        G  1073531
# 286     0.03         1624    205        G   670516
# 297     0.00          201      0        G  2126281
#
#                                TaxName
# 230                  Mycolicibacterium
# 281                     Mycolicibacter
# 286                    Mycobacteroides
# 297                   Mycolicibacillus

# %%
df_kraken_standard_DB.query("TaxLevel=='G' & TaxName.str.contains('Mycobacterium')")
# Out:
#    Percent  Cumul_Count    Count TaxLevel  TaxID  \
# 9    91.09      5465215  1506977        G   1763
#
#                          TaxName
# 9                  Mycobacterium

# %%
df_kraken_standard_DB.query("TaxLevel=='S' & TaxName.str.contains('Mycobacterium')")
# Out:
#      Percent  Cumul_Count   Count TaxLevel    TaxID  \
# 11     37.99      2279317       0        S   339268
# 13     10.40       623690  623690        S   560555
# 14      2.21       132705  132705        S   701042
# 15      1.41        84666   57179        S     1764
# 21      0.55        32768   17245        S     1767
# 28      0.48        28951   28951        S   222805
# 29      0.12         7236    7236        S    64667
# 30      0.07         4392    4392        S  1138383
# 32      2.68       160640  137413        S     1773
# 173     0.19        11547    3830        S    78331
# 180     0.51        30678   30678        S   292462
# 181     0.36        21305   21305        S   185642
# 182     0.31        18388   18388        S    53376
# 183     0.28        16814   16814        S   470076
# 184     0.28        16718   16718        S     1784
# 185     0.28        16518   16518        S   722731
# 186     0.24        14527   14527        S   220927
# 187     0.41        24311   24311        S   590652
# 189     0.08         4967    4967        S   212767
# 190     0.05         3017    3017        S  1682113
# 191     0.03         2016    2016        S  1545728
# 192     0.03         1745    1745        S  2675524
# 193     0.03         1593    1593        S  2675523
# 194     0.03         1588    1588        S  2487344
# 195     0.02         1321    1321        S  1547487
# 196     0.02          933     933        S  1936029
# 197     0.01          702     702        S  1168287
# 198     0.01          470     470        S  2051552
# 199     0.00          211     211        S  2587868
# 200     0.00          210     210        S  2041046
# 201     0.00          200     200        S  1920667
# 202     0.00          187     187        S   189918
# 203     0.00          112     112        S  1561223
# 204     0.33        20048   20048        S    44010
# 205     0.25        15034   15034        S   386911
# 206     0.13         7520    7520        S    43348
# 207     0.12         7407    7407        S  1389713
# 208     0.12         7242    7242        S     1775
# 209     0.11         6455    6455        S   169765
# 210     0.11         6446    6446        S     1768
# 211     0.10         5865    5865        S   398694
# 212     0.08         4523    4523        S   459858
# 213     0.07         4267       0        S    29311
# 215     0.06         3475    3475        S  2094119
# 216     0.05         3089    3089        S     1789
# 217     0.04         2538    2538        S   482462
# 218     0.03         1684    1684        S    39689
# 219     0.03         1535    1404        S     1781
# 222     0.02          989     989        S     1769
# 223     0.01          820     820        S  1552759
# 224     0.00          159     117        S     1809
# 226     0.00          105       0        S   261524
# 228     0.00           25       0        S   265949
# 296     0.00           90      90        S  1520670
#
#                                                TaxName
# 11                           Mycobacterium colombiense
# 13                              Mycobacterium mantenii
# 14                          Mycobacterium marseillense
# 15                                 Mycobacterium avium
# 21                        Mycobacterium intracellulare
# 28                              Mycobacterium chimaera
# 29                          Mycobacterium lepraemurium
# 30                       Mycobacterium paraintracel...
# 32                          Mycobacterium tuberculosis
# 173                             Mycobacterium canettii
# 180                          Mycobacterium florentinum
# 181                             Mycobacterium parmense
# 182                       Mycobacterium heidelbergense
# 183                          Mycobacterium stomatepiae
# 184                               Mycobacterium simiae
# 185                            Mycobacterium shigaense
# 186                      Mycobacterium saskatchewan...
# 187                        Mycobacterium paraseoulense
# 189                            Mycobacterium sp. JS623
# 190                           Mycobacterium sp. YC-RL4
# 191                            Mycobacterium sp. EPa45
# 192                            Mycobacterium sp. DL592
# 193                            Mycobacterium sp. DL440
# 194                             Mycobacterium sp. DL90
# 195                             Mycobacterium sp. ELW1
# 196                           Mycobacterium sp. MS1601
# 197                          Mycobacterium sp. MOTT36Y
# 198                            Mycobacterium sp. PYR15
# 199                          Mycobacterium sp. THAF192
# 200                           Mycobacterium sp. 3/86Rv
# 201                             Mycobacterium sp. WY10
# 202                              Mycobacterium sp. KMS
# 203                           Mycobacterium sp. QIA-37
# 204                           Mycobacterium conspicuum
# 205                            Mycobacterium seoulense
# 206                             Mycobacterium branderi
# 207                         Mycobacterium paragordonae
# 208                               Mycobacterium cookii
# 209                                Mycobacterium lacus
# 210                             Mycobacterium kansasii
# 211                         Mycobacterium shinjukuense
# 212                         Mycobacterium noviomagense
# 213                          Mycobacterium haemophilum
# 215                           Mycobacterium basiliense
# 216                               Mycobacterium xenopi
# 217                     Mycobacterium dioxanotrophicus
# 218                           Mycobacterium gallinarum
# 219                              Mycobacterium marinum
# 222                               Mycobacterium leprae
# 223                             Mycobacterium grossiae
# 224                             Mycobacterium ulcerans
# 226                            Mycobacterium liflandii
# 228                       Mycobacterium pseudoshottsii
# 296                    [Mycobacterium] stephanolepidis

# %%
df_kraken_standard_DB.query("TaxLevel=='S' & TaxName.str.contains('leprae')")
# Out:
#      Percent  Cumul_Count  Count TaxLevel  TaxID  \
# 29      0.12         7236   7236        S  64667
# 222     0.02          989    989        S   1769
#
#                                             TaxName
# 29                       Mycobacterium lepraemurium
# 222                            Mycobacterium leprae

# %%
df_kraken_custom_DB
# Out:
#     Percent  Cumul_Count    Count TaxLevel    TaxID  \
# 0     63.42      3804670  3804670        U        0
# 1     36.58      2194920        0        R        1
# 2     36.58      2194920        0       R1   131567
# 3     36.58      2194920        0        D        2
# 4     36.58      2194920        0       D1  1783272
# 5     36.58      2194920        0        P   201174
# 6     36.58      2194920        0        C     1760
# 7     36.58      2194920        0        O    85007
# 8     36.58      2194920        0        F     1762
# 9     36.58      2194920        0        G     1763
# 10    36.58      2194920        0       G1    77643
# 11    36.58      2194920  2193423        S     1773
# 12     0.01          774      774       S1    83331
# 13     0.00          282      282       S1   336982
# 14     0.00          221      221       S1    83332
# 15     0.00          220      220       S1   707235
#
#                                               TaxName
# 0                                        unclassified
# 1                                                root
# 2                                  cellular organisms
# 3                                            Bacteria
# 4                                 Terrabacteria group
# 5                                      Actinomycetota
# 6                                       Actinomycetes
# 7                                     Mycobacteriales
# 8                                    Mycobacteriaceae
# 9                                       Mycobacterium
# 10                    Mycobacterium tuberculosis c...
# 11                         Mycobacterium tuberculosis
# 12                        Mycobacterium tuberculos...
# 13                        Mycobacterium tuberculos...
# 14                        Mycobacterium tuberculos...
# 15                        Mycobacterium tuberculos...

# %%
df_kraken_contaminants.sort_values("SampleID").to_csv("Kraken_Contamination_analysis.csv", index=False)

# %%
df_trust_patients = pd.read_csv("/n/data1/hms/dbmi/farhat/rollingDB/TRUST/clinical_data/20241127_combined_patients_WGS_samples.csv")

# %%
df_trust_patients.query("pid=='T0091'")
# Out:
#       pid Original_ID SampleID  specimen_time_point         SampleLib  Pacbio  \
# 23  T0091    S0091-05  MFS-736                  5.0  MFS-736_lib72899     NaN
# 24  T0091    S0091-01  MFS-564                  1.0  MFS-564_lib64404     NaN
# 25  T0091    S0091-07  MFS-565                  7.0  MFS-565_lib64405     NaN
#
#    Comment  quality  Cov_Any_Mean  Cov_Unam_Perc  ...      fib4  \
# 23     NaN      1.0        517.84           0.99  ...  1.457014
# 24     NaN      1.0        323.86           0.99  ...  1.457014
# 25     NaN      1.0        193.82           0.98  ...  1.457014
#
#     prevtb_outcome  total_adherence  adherence_12week  first_dots_date  \
# 23             NaN         0.298851          0.440678                8
# 24             NaN         0.298851          0.440678                8
# 25             NaN         0.298851          0.440678                8
#
#     last_dots_date        F2 Coll2014 Freschi2020 Lineage
# 23             132  0.007203  4.1.1.1  4.1.i1.2.1     4.0
# 24             132  0.008389  4.1.1.1  4.1.i1.2.1     4.0
# 25             132       NaN      NaN         NaN     NaN
#
# [3 rows x 7102 columns]

# %%
# df_kraken_standard_DB.query("TaxLevel=='S'").sort_values("Percent", ascending=False)['TaxName'].values[0]

# %%
df_kraken_standard_DB.loc[(df_kraken_standard_DB[3]=='G') & (df_kraken_standard_DB[5].str.contains('Mycobacterium'))]
# Out:
#        0        1        2  3     4                              5
# 9  91.09  5465215  1506977  G  1763                  Mycobacterium

# %%
df_kraken_standard_DB.loc[(df_kraken_standard_DB[3]=='G1') & (df_kraken_standard_DB[5].str.contains('Mycobacterium'))]
# Out:
#          0        1       2   3        4  \
# 10   55.54  3331901  138176  G1   120793
# 31    5.63   337931  165744  G1    77643
# 179   2.38   143037    8089  G1  2249310
# 188   0.36    21832    2560  G1  2642494
#
#                                                      5
# 10                     Mycobacterium avium complex ...
# 31                     Mycobacterium tuberculosis c...
# 179                       Mycobacterium simiae complex
# 188                         unclassified Mycobacterium

# %%
# Out:
#         0      1     2   3        4  \
# 188  0.36  21832  2560  G1  2642494
#
#                                                 5
# 188                    unclassified Mycobacterium

# %%
df_kraken_standard_DB
# Out:
#           0        1       2   3        4                                 5
# 0      6.71   402582  402582   U        0                      unclassified
# 1     93.29  5597010      83   R        1                              root
# 2     93.29  5596922    1084  R1   131567                cellular organisms
# 3     92.98  5578421    5774   D        2                          Bacteria
# 4     92.65  5558601     351  D1  1783272               Terrabacteria group
# ...     ...      ...     ...  ..      ...                               ...
# 3278   0.00        1       0   O  2732527                      Chitovirales
# 3279   0.00        1       0   F    10240                        Poxviridae
# 3280   0.00        1       0  F1    10241                  Chordopoxvirinae
# 3281   0.00        1       0   G    10270                    Leporipoxvirus
# 3282   0.00        1       1   S    10273                      Myxoma virus
#
# [3283 rows x 6 columns]

# %%
df_kraken_standard_DB.loc[(df_kraken_standard_DB[3]=='G') & df_kraken_standard_DB[5].str.contains('Homo')][5].values
# Out:
# array(['                                                            Homo'],
#       dtype=object)

# %%
df_kraken_standard_DB.loc[(df_kraken_standard_DB[3]=='G') & df_kraken_standard_DB[5].str.contains('Homo')]
# Out:
#          0      1  2  3     4  \
# 3146  0.28  16947  0  G  9605
#
#                                                       5
# 3146                                                ...

# %%
df_kraken_standard_DB.loc[(df_kraken_standard_DB[3]=='S') & df_kraken_standard_DB[5].str.contains('Homo')]
# Out:
#          0      1      2  3     4  \
# 3147  0.28  16947  16947  S  9606
#
#                                                       5
# 3147                                                ...

# %%
df_kraken_standard_DB.loc[(df_kraken_standard_DB[3].isin(['S'])) & (df_kraken_standard_DB[0] > 1)]
# Out:
#         0        1        2  3     4  \
# 32  99.86  2480851  2480851  S  9606
#
#                                                     5
# 32                                                ...

# %%
df_kraken_standard_DB.loc[(df_kraken_standard_DB[3].isin(['S'])) & (df_kraken_standard_DB[0] > 1)][5].values
# Out:
# array(['                                                              Homo sapiens'],
#       dtype=object)

# %%
df_kraken_standard_DB.loc[(df_kraken_standard_DB[3].isin(['G1', 'S'])) & (df_kraken_standard_DB[0] > 1)]
# Out:
#          0        1       2   3        4  \
# 10   55.54  3331901  138176  G1   120793
# 11   37.99  2279317       0   S   339268
# 13   10.40   623690  623690   S   560555
# 14    2.21   132705  132705   S   701042
# 15    1.41    84666   57179   S     1764
# 31    5.63   337931  165744  G1    77643
# 32    2.68   160640  137413   S     1773
# 179   2.38   143037    8089  G1  2249310
#
#                                                      5
# 10                     Mycobacterium avium complex ...
# 11                           Mycobacterium colombiense
# 13                              Mycobacterium mantenii
# 14                          Mycobacterium marseillense
# 15                                 Mycobacterium avium
# 31                     Mycobacterium tuberculosis c...
# 32                          Mycobacterium tuberculosis
# 179                       Mycobacterium simiae complex

# %%
df_kraken_standard_DB.loc[(df_kraken_standard_DB[3].isin(['G1', 'G2'])) & (df_kraken_standard_DB[0] > 0)][5].values
# Out:
# array(['                  Mycobacterium avium complex (MAC)',
#        '                  Mycobacterium tuberculosis complex',
#        '                  Mycobacterium simiae complex',
#        '                  unclassified Mycobacterium',
#        '                  unclassified Rhodococcus',
#        '                  unclassified Streptomyces',
#        '                  unclassified Amycolatopsis',
#        '                  unclassified Pseudonocardia',
#        '                  unclassified Streptosporangium',
#        '                  unclassified Nocardioides',
#        '                unclassified Bradyrhizobium',
#        '                Burkholderia cepacia complex'], dtype=object)

# %%
# Out:
#        0       1       2   3      4  \
# 31  5.63  337931  165744  G1  77643
#
#                                                     5
# 31                    Mycobacterium tuberculosis c...

# %%
df_kraken_standard_DB.loc[(df_kraken_standard_DB[3].isin(['G1'])) & (df_kraken_standard_DB[0] > 0)][0].sum()
# Out:
# 64.02000000000001

# %%
df_kraken_standard_DB.loc[df_kraken_standard_DB[5].str.contains('Mycobacter')]
# Out:
#          0       1      2   3        4  \
# 26    8.15  383660  40880   F     1762
# 78    3.06  144168  48367   G     1763
# 79    0.59   27927   2908  G1  2642494
# 80    0.09    4134   4134   S  1936029
# 81    0.07    3513   3513   S   212767
# ...    ...     ...    ...  ..      ...
# 272   0.01     576    576  S1  2480908
# 273   0.03    1448   1448   S   404941
# 274   0.02     737    737   S  1520670
# 5020  0.00       6      6   S   205872
# 5023  0.00       1      1   S  1647305
#
#                                                       5
# 26                                     Mycobacteriaceae
# 78                                        Mycobacterium
# 79                           unclassified Mycobacterium
# 80                             Mycobacterium sp. MS1601
# 81                              Mycobacterium sp. JS623
# ...                                                 ...
# 272                       [Mycobacterium] chelonae s...
# 273                       Mycobacteroides salmoniphilum
# 274                     [Mycobacterium] stephanolepidis
# 5020                          Mycobacterium virus Che9c
# 5023                       Mycobacterium phage Cambiare
#
# [200 rows x 6 columns]

# %% [markdown]
# # Analysis of Mixed-Lineage Samples

# %%
mixed_lineage_samples = df_TRUST.dropna(subset='Freschi2020').query("Freschi2020.str.contains(',') | Coll2014.str.contains(',')").SampleID.values

len(mixed_lineage_samples)
# Out:
# 11

# %%
for sample in mixed_lineage_samples:

    df_minor_allele_fractions = pd.read_csv(f"{genomic_data_dir}/{sample}/lineage/minor_allele_fractions.csv")
    print(len(df_minor_allele_fractions))
# Out:
# 57
# 57
# 57
# 57
# 57
# 57
# 57
# 57
# 57
# 57
# 57

# %%
df_minor_allele_fractions.Lineage.nunique()
# Out:
# 57

# %%
df_minor_allele_fractions
# Out:
#      Lineage  Fraction
# 0      4.1.1  0.259770
# 1      2.2.1  0.259054
# 2        4.1  0.257591
# 3          2  0.256745
# 4        2.2  0.255687
# 5    4.1.1.3  0.254534
# 6          4  0.248029
# 7    4.1.1.1  0.016323
# 8      4.2.2  0.008908
# 9    4.2.2.1  0.008248
# 10   4.4.1.1  0.008076
# 11       2.1  0.007500
# 12   2.2.1.2  0.006564
# 13   1.1.1.1  0.006118
# 14       1.1  0.005329
# 15     1.2.1  0.004994
# 16     4.3.2  0.004647
# 17     2.2.2  0.004064
# 18   3.1.2.2  0.003945
# 19         7  0.003681
# 20         3  0.003663
# 21       4.8  0.003502
# 22   4.3.2.1  0.003464
# 23   2.2.1.1  0.003383
# 24       4.2  0.003236
# 25     4.6.1  0.003156
# 26         5  0.003111
# 27     4.3.1  0.003069
# 28  BOV_AFRI  0.003056
# 29       4.4  0.003011
# 30     1.1.2  0.003002
# 31     1.2.2  0.002918
# 32     4.4.1  0.002905
# 33   4.6.2.2  0.002870
# 34         6  0.002846
# 35   4.1.1.2  0.002833
# 36     4.2.1  0.002747
# 37   4.6.1.1  0.002719
# 38     4.6.2  0.002686
# 39   4.6.2.1  0.002669
# 40       4.9  0.002585
# 41     1.1.1  0.002579
# 42   4.1.2.1  0.002560
# 43   4.3.4.2  0.002509
# 44   4.4.1.2  0.002501
# 45         1  0.002491
# 46     4.3.3  0.002426
# 47       4.3  0.002395
# 48     1.1.3  0.002192
# 49       BOV  0.002178
# 50     3.1.1  0.002083
# 51   4.6.1.2  0.002081
# 52     4.4.2  0.002071
# 53       4.5  0.002004
# 54   4.3.4.1  0.001948
# 55     4.3.4  0.001833
# 56   3.1.2.1  0.001415

# %% [markdown]
# # Get all patient data

# %%
# df_trust_patients = pd.read_csv("processed_data/20240925_combined_patients_WGS_samples_all.csv")
df_full_WGS = pd.read_csv("/n/data1/hms/dbmi/farhat/rollingDB/TRUST/clinical_data/20241127_combined_patients_WGS_samples.csv").dropna(subset='Lineage').reset_index(drop=True)
print(df_full_WGS.pid.nunique())

df_full = pd.read_csv("raw_data/20240826_metadata_MIC_method_updates.csv")
print(df_full.pid.nunique())

#df_pids_high_quality_WGS = df_trust_patients.dropna(subset='F2')#.query("F2 <= 0.05")
#print(f"Kept {df_pids_high_quality_WGS.SampleID.nunique()}/{df_trust_patients.SampleID.nunique()} high-quality WGS samples across {df_pids_high_quality_WGS.pid.nunique()} pids")
# Out:
# 416
# 452

# %%
# for i, row in df_full_WGS.iterrows():
    
#     if not pd.isnull(row['Original_ID']):

#         split_name = row['Original_ID'].split('-')[1]
        
#         if split_name == 'm5':
#             df_full_WGS.loc[i, 'specimen_time_point'] = 13
#         elif split_name == '01A':
#             df_full_WGS.loc[i, 'specimen_time_point'] = 15
#         else:
#             df_full_WGS.loc[i, 'specimen_time_point'] = int(split_name)

np.sort(df_full_WGS.specimen_time_point.unique())

# %%
def read_combine_all_TRUST_data(patient_WGS_data_fName, CNN_results_dir="/n/data1/hms/dbmi/farhat/Sanjana/CNN_results", F2_thresh=0.03, baseline_only=True):
    '''
    This function keeps only measured MICs and WGS samples taken in the first two weeks of treatment because we are interested in associating baseline characteristics with outcome.
    '''

    ############################################# STEP 1: READ IN THE COMBINED PATIENT-WGS DATAFRAME #############################################

    
    df_trust_patients = pd.read_csv(patient_WGS_data_fName)
    
    print(f"{df_trust_patients.pid.nunique()} patients with any WGS samples")

    # fix lineages. Sometimes the names got converted to integers for the single number lineages
    for i, row in df_trust_patients.iterrows():
        if not pd.isnull(row['Lineage']):
            if type(row['Lineage']) != str:
                df_trust_patients.loc[i, 'Lineage'] = str(int(row['Lineage']))
    
    df_trust_patients['Lineage'] = df_trust_patients['Lineage'].astype(str)
    df_trust_patients['Lineage'] = df_trust_patients['Lineage'].replace('nan', np.nan)

    # keep only WGS samples that were not contaminated. Low sequencing depth isn't an issue here, they were all sequenced to very high depths
    df_trust_patients = df_trust_patients.dropna(subset='F2').reset_index(drop=True)
    
    print(f"{df_trust_patients.pid.nunique()} patients with uncontaminated WGS samples")

    
    ######################################### STEP 2: KEEP ONLY SEQUENCES COLLECTED IN THE FIRST 2 WEEKS ##############################################


    # get the sample week
    df_trust_patients['sample_collection_week'] = df_trust_patients['Original_ID'].str.split('-').str[1]
    
    # replace month 5 with 20 for weeks
    df_trust_patients['sample_collection_week'] = df_trust_patients['sample_collection_week'].replace('01A', '01').replace('m5', '20')
    
    df_trust_patients['sample_collection_week'] = df_trust_patients['sample_collection_week'].astype(int)
    
    # keep only WGS samples collected in the first 2 weeks
    if baseline_only:
        df_trust_patients = df_trust_patients.query("sample_collection_week <= 2").reset_index(drop=True)
    
        print(f"{df_trust_patients.pid.nunique()} patients with uncontaminated WGS samples taken in the first 2 weeks\n")

    
    ###################################################### STEP 3: ADD LINEAGE ANNOTATIONS ######################################################

    
    # add additional lineage information on mixed infections and primary lineage group
    df_trust_patients['mixed_infect'] = (df_trust_patients['F2'] > F2_thresh).astype(int)

    df_trust_patients.loc[pd.isnull(df_trust_patients['F2']), 'mixed_infect'] = np.nan
    
    df_trust_patients.loc[df_trust_patients['Lineage'].isin(['1', '3', '1,3']), 'L1_L3'] = 1
    df_trust_patients.loc[df_trust_patients['Lineage'].isin(['2', '4', '2,4']), 'L1_L3'] = 0
    df_trust_patients.loc[df_trust_patients['Lineage'].isin(['1,2', '2,3', '3,4']), 'L1_L3'] = 0.5
    
    df_trust_patients.loc[pd.isnull(df_trust_patients['Lineage']), 'L1_L3'] = np.nan

    
    ###################################################### STEP 4: REMOVE PATIENTS WITH SEQUENCING AT THE SAME TIMEPOINT WITH DIFFERENT LINEAGES ###########################
    

    pids_multiple_sequences_same_timepoint = df_trust_patients.iloc[df_trust_patients.index.values[df_trust_patients.duplicated('Original_ID', keep=False)]].pid.unique()

    pids_multiple_sequences_same_timepoint_discordant_lineages = pd.DataFrame(df_trust_patients.groupby(['pid', 'Original_ID'])['Coll2014'].nunique()).query("Coll2014 > 1").reset_index().pid.values
    
    print(f"{len(pids_multiple_sequences_same_timepoint)} patients: {pids_multiple_sequences_same_timepoint} have multiple sequences at the same timepoint")
    print(f"Removing patients {pids_multiple_sequences_same_timepoint_discordant_lineages} because there are multiple WGS samples at the same timepoint with different lineages")

    df_trust_patients = df_trust_patients.query("pid not in @pids_multiple_sequences_same_timepoint_discordant_lineages")
    
    
    ###################################################### STEP 5: READ IN ALL AVAILABLE MEASURED MICS ######################################################

    
    TRUST_phenos = []
    
    for drug in drugs_lst:
        
        # this contains all WGS runs, so keep only the unique pids for counting/plotting purposes
        # all MICs here were converted to MGIT. The only drug for which that makes any difference is INH, whose MGIT (0.1) and 7H10 (0.2) critical concentrations are different.
        df_single_drug = get_all_available_MICs_single_drug(df_trust_patients, drug, baseline_only=baseline_only)
        df_single_drug = df_single_drug[['pid', drug, f"{drug}_method"]]
        
        print(f"{len(df_single_drug)} patients have MICs for {drug}")
        TRUST_phenos.append(df_single_drug)
    
    TRUST_phenos = reduce(lambda left, right: pd.merge(left, right, on='pid', how='outer'), TRUST_phenos).drop_duplicates()
    
    for drug in drugs_lst:
        if drug in TRUST_phenos.columns:
            TRUST_phenos = convert_categorical_to_actual_MICs(TRUST_phenos, drug, MIC_encoding_dicts[drug])

    if baseline_only:
        print(f"{TRUST_phenos.pid.nunique()} patients have measured MICs in the first 2 weeks\n")
    else:
        print(f"{TRUST_phenos.pid.nunique()} patients have measured MICs\n")

    
    #################################################### STEP 6: READ IN ALL AVAILABLE PREDICTED MICS #########################################################

    
    df_pred_combined = []
    
    for drug in drugs_lst:
        df_pred = pd.read_csv(os.path.join(CNN_results_dir, f"{drug}_lineage_amino_acid", "TRUST", "test_predictions.csv")).rename(columns={'ROLLINGDB_ID': 'SampleID', 'pred_MIC': f'{drug}_pred_MIC'})
        
        # drop patient duplicates (because multiple WGS samples per pid)
        df_pred = df_pred.merge(df_trust_patients[['SampleID', 'Original_ID', 'pid']]).sort_values(['pid', 'Original_ID']).drop_duplicates('pid', keep='first').reset_index(drop=True)
    
        print(f"Found predicted {drug} MICs for {len(df_pred)} pids")
        
        df_pred_combined.append(df_pred[['pid', f'{drug}_pred_MIC']])
    
    df_pred_combined = reduce(lambda left, right: pd.merge(left, right, on='pid', how='outer'), df_pred_combined)
    print(f"{df_pred_combined.pid.nunique()} patients have predicted MICs")

    # these should have all the same patients because the predicted MICs come from the high-quality WGS samples 
    assert len(set(df_trust_patients.pid).symmetric_difference(df_pred_combined.pid)) == 0

    return df_trust_patients, TRUST_phenos, df_pred_combined

# %%
df_trust_patients, TRUST_phenos, df_pred_combined = read_combine_all_TRUST_data("./processed_data/combined_patients_WGS_samples.csv", baseline_only=True)

# also run on this so that the variables are in better encodings
df_trust_patients = process_patient_metadata_better_encodings(df_trust_patients, TRUST_phenos, df_TTP_smear=None, include_TTP=False)
df_trust_patients.pid.nunique()
# Out:
# 418 patients with any WGS samples
# 416 patients with uncontaminated WGS samples
# 404 patients with uncontaminated WGS samples taken in the first 2 weeks
#
# 2 patients: ['T0137' 'T0402'] have multiple sequences at the same timepoint
# Removing patients ['T0402'] because there are multiple WGS samples at the same timepoint with different lineages
# 405 patients have MICs for RIF
# 405 patients have MICs for INH
# 405 patients have MICs for EMB
# 284 patients have MICs for PZA
# 401 patients have measured MICs in the first 2 weeks
#
# Found predicted RIF MICs for 403 pids
# Found predicted INH MICs for 403 pids
# Found predicted EMB MICs for 403 pids
# Found predicted PZA MICs for 403 pids
# 403 patients have predicted MICs
# 403

# %%
df_trust_patients.columns[df_trust_patients.columns.str.startswith('ct_')]
# Out:
# Index(['ct_date_baseline', 'ct_gxpver_baseline', 'ct_cartlot_baseline',
#        'ct_cartserial_baseline', 'ct_modserial_baseline',
#        'ct_instserial_baseline', 'ct_probea_baseline', 'ct_probeb_baseline',
#        'ct_probec_baseline', 'ct_probed_baseline', 'ct_probee_baseline',
#        'ct_spc_baseline', 'ct_isct_baseline', 'ct_rpo1_baseline',
#        'ct_rpo2_baseline', 'ct_rpo3_baseline', 'ct_rpo4_baseline',
#        'ct_spcultra_baseline', 'ct_isendpt_baseline', 'ct_rpo1endpt_baseline',
#        'ct_rpo2endpt_baseline', 'ct_rpo3endpt_baseline',
#        'ct_rpo4endpt_baseline', 'ct_spcendpt_baseline',
#        'ct_values_complete_additional_visit', 'ct_values_complete_baseline',
#        'ct_combined', 'ct_combined_categorical', 'ct_type'],
#       dtype='object')

# %%
df_trust_patients.query("pid=='T0402'")
# Out:
# Empty DataFrame
# Columns: [pid, Original_ID, SampleID, SampleLib, Pacbio, Comment, quality, Cov_Any_Mean, Cov_Unam_Perc, Perc_Reads_Mapped, Excluded, repeat_pcrfree_1, transfered_pcrfree, transfered_pacbio, 250x, repeat_pcrfree, shipment, status, comment, Coll2014_Annotated, patient_num, sample_week, screen_version, screen_date, screen_ic, screen_icdate, screen_parentic___1, screen_icversion, screen_reenroll, screen_prevpid, screen_sex, screen_race, screen_alc, screen_age, screen_years, screen_ageest___1, screen_txinitiate, screen_tbpos, screen_comply, screen_ephx, screen_ephx_2, screen_preg, screen_pregtest___1, screen_pregdate, screen_prevtx_4mths, screen_eptb, screen_rrtb, screen_hivtest, screen_hivdate, screen_prevtx, screen_hiv, screen_pkic, screen_pknoenroll, screen_pkicdate, screen_pkparentic___1, screen_final, screen_trust2, screen_trust1vs2, screen_paper, screen_staff, screen_crfdate, screen_verstaff, screen_verdate, screen_datastaff, screen_datadate, screening_complete, screen_version_add_additional_visit, screen_date_add_additional_visit, screen_ic_add_additional_visit, screen_icdate_add_additional_visit, screen_parentic_add___1_additional_visit, screen_previd_add_additional_visit, screen_sex_add_additional_visit, screen_race_add_additional_visit, screen_alc_add_additional_visit, screen_age_add_additional_visit, screen_birthyr_add_additional_visit, screen_years_add_additional_visit, screen_ageest_add___1_additional_visit, screen_txinitiate_add_additional_visit, screen_tbpos_add_additional_visit, screen_comply_add_additional_visit, screen_prevtrust_add_additional_visit, screen_prevtx_4mths_add_additional_visit, screen_eptb_add_additional_visit, screen_final_add_additional_visit, screen_trust2_add_additional_visit, screen_paper_add_additional_visit, screen_staff_add_additional_visit, screen_crfdate_add_additional_visit, screen_verstaff_add_additional_visit, screen_verdate_add_additional_visit, screening_additional_visit_complete_additional_visit, bl_version, bl_date, bl_txinitdate, bl_weight, bl_height, bl_bmi, bl_ed, ...]
# Index: []
#
# [0 rows x 7101 columns]

# %%
df_trust_patients.loc[pd.isnull(df_trust_patients['Original_ID'])]
# Out:
# Empty DataFrame
# Columns: [pid, Original_ID, SampleID, SampleLib, Pacbio, Comment, quality, Cov_Any_Mean, Cov_Unam_Perc, Perc_Reads_Mapped, Excluded, repeat_pcrfree_1, transfered_pcrfree, transfered_pacbio, 250x, repeat_pcrfree, shipment, status, comment, Coll2014_Annotated, patient_num, sample_week, screen_version, screen_date, screen_ic, screen_icdate, screen_parentic___1, screen_icversion, screen_reenroll, screen_prevpid, screen_sex, screen_race, screen_alc, screen_age, screen_years, screen_ageest___1, screen_txinitiate, screen_tbpos, screen_comply, screen_ephx, screen_ephx_2, screen_preg, screen_pregtest___1, screen_pregdate, screen_prevtx_4mths, screen_eptb, screen_rrtb, screen_hivtest, screen_hivdate, screen_prevtx, screen_hiv, screen_pkic, screen_pknoenroll, screen_pkicdate, screen_pkparentic___1, screen_final, screen_trust2, screen_trust1vs2, screen_paper, screen_staff, screen_crfdate, screen_verstaff, screen_verdate, screen_datastaff, screen_datadate, screening_complete, screen_version_add_additional_visit, screen_date_add_additional_visit, screen_ic_add_additional_visit, screen_icdate_add_additional_visit, screen_parentic_add___1_additional_visit, screen_previd_add_additional_visit, screen_sex_add_additional_visit, screen_race_add_additional_visit, screen_alc_add_additional_visit, screen_age_add_additional_visit, screen_birthyr_add_additional_visit, screen_years_add_additional_visit, screen_ageest_add___1_additional_visit, screen_txinitiate_add_additional_visit, screen_tbpos_add_additional_visit, screen_comply_add_additional_visit, screen_prevtrust_add_additional_visit, screen_prevtx_4mths_add_additional_visit, screen_eptb_add_additional_visit, screen_final_add_additional_visit, screen_trust2_add_additional_visit, screen_paper_add_additional_visit, screen_staff_add_additional_visit, screen_crfdate_add_additional_visit, screen_verstaff_add_additional_visit, screen_verdate_add_additional_visit, screening_additional_visit_complete_additional_visit, bl_version, bl_date, bl_txinitdate, bl_weight, bl_height, bl_bmi, bl_ed, ...]
# Index: []
#
# [0 rows x 7101 columns]

# %%
df_trust_patients.query("pid=='T0137'")
# Out:
#       pid Original_ID SampleID         SampleLib  Pacbio Comment  quality  \
# 20  T0137    S0137-01  MFS-746  MFS-746_lib72909     NaN     NaN      1.0
# 21  T0137    S0137-01  MFS-600  MFS-600_lib65706     NaN     NaN      1.0
#
#     Cov_Any_Mean  Cov_Unam_Perc  Perc_Reads_Mapped  ...        F2  Coll2014  \
# 20        339.27           0.99             0.9841  ...  0.020100     4.1.2
# 21        361.13           0.99             0.9862  ...  0.018452     4.1.2
#
#      Freschi2020  Lineage  sample_collection_week  mixed_infect L1_L3  \
# 20  4.1.i1.1.1.1        4                       1           0.0   0.0
# 21  4.1.i1.1.1.1        4                       1           0.0   0.0
#
#    bilateral_infiltrates diabetes inh_resistant
# 20                   0.0        0           0.0
# 21                   0.0        0           0.0
#
# [2 rows x 7101 columns]

# %%
pids_multiple_sequences_same_timepoint_discordant_lineages
# Out:
#              Coll2014
# Original_ID
# S0402-01            2

# %%
lineage_col = 'Lineage'

pids_with_differing_lineages = pd.DataFrame(df_full_WGS.groupby('pid')[lineage_col].nunique()).query(f"{lineage_col} > 1").reset_index()
print(f"{len(pids_with_differing_lineages)} pids have different lineages in the {lineage_col} column")
# Out:
# 22 pids have different lineages in the Lineage column

# %%
df_full_WGS.query("pid=='T0010'")
# Out:
#        pid Original_ID SampleID         SampleLib  Pacbio Comment  quality  \
# 412  T0010    S0010-08  MFS-337  MFS-337_lib58949     NaN     NaN      1.0
# 413  T0010    S0010-01  MFS-336  MFS-336_lib58948     NaN     NaN      1.0
#
#      Cov_Any_Mean  Cov_Unam_Perc  Perc_Reads_Mapped  ...  prevtb_outcome  \
# 412        404.13           0.99             0.9900  ...             NaN
# 413        338.54           1.00             0.9895  ...             NaN
#
#      total_adherence  adherence_12week  first_dots_date  last_dots_date  \
# 412             0.96          0.983333                5             183
# 413             0.96          0.983333                5             183
#
#            F2         Coll2014           Freschi2020 Lineage  \
# 412  0.012046          2.2.1.1             2.2.1.1.1       2
# 413  0.458952  4.1.1.1,2.2.1.1  4.1.i1.2.1,2.2.1.1.1     2,4
#
#     specimen_time_point
# 412                 8.0
# 413                 1.0
#
# [2 rows x 7102 columns]

# %%
# df_full_WGS.query("pid in @pids_with_differing_lineages.pid").sort_values(['pid', 'specimen_time_point'])[['pid', 'Original_ID', 'SampleID', 'specimen_time_point', 'Coll2014', 'Lineage', 'F2']]

# %%
len(df_full_WGS), df_full_WGS.Original_ID.nunique()
# Out:
# (727, 723)

# %%
df_full_WGS.iloc[df_full_WGS.index.values[df_full_WGS.duplicated(subset='Original_ID', keep=False)]].sort_values(['pid', 'Original_ID'])[['pid', 'Original_ID', 'SampleID', 'Excluded', 'Lineage', 'Coll2014', 'F2']].sort_values(['pid', 'SampleID'])
# Out:
#       pid Original_ID SampleID  Excluded Lineage Coll2014        F2
# 32  T0114    S0114-04  MFS-365       NaN     4.0  4.3.2.1  0.009635
# 30  T0114    S0114-04  MFS-742       0.0     4.0      4.8  0.140563
# 37  T0137    S0137-01  MFS-600       0.0     4.0    4.1.2  0.018452
# 36  T0137    S0137-01  MFS-746       0.0     4.0    4.1.2  0.020100
# 83  T0395    S0395-08  MFS-489       NaN     4.0    4.3.3  0.006334
# 81  T0395    S0395-08  MFS-779       0.0     4.0    4.3.3  0.006367
# 90  T0402    S0402-01  MFS-676       0.0     2.0  2.2.1.1  0.009952
# 89  T0402    S0402-01  MFS-784       0.0     3.0        3  0.009796

# %%
df_full_WGS.query("pid=='T0114'")
# Out:
#       pid Original_ID SampleID  specimen_time_point         SampleLib  Pacbio  \
# 30  T0114    S0114-04  MFS-742                  4.0  MFS-742_lib72905     NaN
# 31  T0114    S0114-01  MFS-364                  1.0  MFS-364_lib59185     NaN
# 32  T0114    S0114-04  MFS-365                  4.0  MFS-365_lib59186     NaN
#
#    Comment  quality  Cov_Any_Mean  Cov_Unam_Perc  ...      fib4  \
# 30     NaN      1.0        321.11            1.0  ...  0.282037
# 31     NaN      1.0        254.42            1.0  ...  0.282037
# 32     NaN      1.0        217.44            1.0  ...  0.282037
#
#     prevtb_outcome  total_adherence  adherence_12week  first_dots_date  \
# 30             NaN         0.958333          0.929825                3
# 31             NaN         0.958333          0.929825                3
# 32             NaN         0.958333          0.929825                3
#
#     last_dots_date        F2 Coll2014         Freschi2020 Lineage
# 30             181  0.140563      4.8  4.2.1.1.1.1.1.1.i1     4.0
# 31             181  0.010288  4.3.2.1      4.2.1.2.1.1.i1     4.0
# 32             181  0.009635  4.3.2.1      4.2.1.2.1.1.i1     4.0
#
# [3 rows x 7102 columns]

# %%
df_trust_WGS_metadata.query("Original_ID=='S0114-04'").sort_values("Report_File")
# Out:
#     SampleID         SampleLib Original_ID  Pacbio Comment  quality  \
# 494  MFS-365  MFS-365_lib59186    S0114-04     NaN     NaN      1.0
# 24   MFS-742  MFS-742_lib72905    S0114-04     NaN     NaN      1.0
#
#      Cov Any Mean  Cov Unam Perc  Perc. Reads Mapped  Excluded  ...  \
# 494        217.44            1.0              0.9894       NaN  ...
# 24         321.11            1.0              0.9869       0.0  ...
#
#      transfered_pacbio  Unnamed: 13  250x                        Report_File  \
# 494                NaN          NaN   NaN  2023-09-01_report_Farhat.v09.xlsx
# 24                 0.0          NaN   NaN         2024-11-13_report.v10.xlsx
#
#      repeat_pacbio repeat_pcrfree  shipment       status comment  \
# 494            NaN            NaN       3rd  in progress       -
# 24             NaN            NaN       NaN          NaN     NaN
#
#     phylogenetic classification (Coll et al., 2014)
# 494                                     4.3.2.1 LAM
# 24                                              NaN
#
# [2 rows x 22 columns]

# %%
df_trust_WGS_metadata.query("Original_ID=='S0402-01'").sort_values("Report_File")
# Out:
#     SampleID         SampleLib Original_ID  Pacbio Comment  quality  \
# 319  MFS-676  MFS-676_lib66549    S0402-01     NaN     NaN      1.0
# 66   MFS-784  MFS-784_lib73059    S0402-01     NaN     NaN      1.0
#
#      Cov Any Mean  Cov Unam Perc  Perc. Reads Mapped  Excluded  ...  \
# 319        335.78           0.99              0.9885       0.0  ...
# 66         295.37           1.00              0.9877       0.0  ...
#
#      transfered_pacbio  Unnamed: 13  250x                 Report_File  \
# 319                NaN          NaN   NaN  2024-05-27_report.v10.xlsx
# 66                 0.0          NaN   NaN  2024-11-13_report.v10.xlsx
#
#      repeat_pacbio repeat_pcrfree  shipment  status comment  \
# 319            NaN            NaN       NaN     NaN     NaN
# 66             NaN            NaN       NaN     NaN     NaN
#
#     phylogenetic classification (Coll et al., 2014)
# 319                                             NaN
# 66                                              NaN
#
# [2 rows x 22 columns]

# %%
df_trust_WGS_metadata.query("SampleID in ['MFS-39', 'MFS-40', 'MFS-270', 'MFS-280']")
# Out:
#     SampleID         SampleLib Original_ID  Pacbio Comment  quality  \
# 573   MFS-39   MFS-39_lib47026       66-01     NaN     NaN      1.0
# 703   MFS-40   MFS-40_lib47027       66-08     NaN     NaN      1.0
# 767  MFS-270  MFS-270_lib51740    S0267-01     NaN     NaN      1.0
# 797  MFS-280  MFS-280_lib52221    S0267-06     NaN     NaN      1.0
#
#      Cov Any Mean  Cov Unam Perc  Perc. Reads Mapped  Excluded  ...  \
# 573        267.14           1.00              0.9861       NaN  ...
# 703        393.45           0.99              0.9854       NaN  ...
# 767        297.53           1.00              0.9885       NaN  ...
# 797        253.25           1.00              0.9897       NaN  ...
#
#      transfered_pacbio  Unnamed: 13  250x                        Report_File  \
# 573                NaN          NaN   NaN  2023-01-24_report_Farhat.v09.xlsx
# 703                NaN          NaN   NaN  2023-01-24_report_Farhat.v09.xlsx
# 767                NaN          NaN   NaN  2023-01-24_report_Farhat.v09.xlsx
# 797                NaN          NaN   NaN  2023-01-24_report_Farhat.v09.xlsx
#
#      repeat_pacbio repeat_pcrfree  shipment    status comment  \
# 573            NaN            NaN       1st  finished       -
# 703            NaN            NaN       1st  finished       -
# 767            NaN            NaN       2nd  finished       -
# 797            NaN            NaN       2nd  finished       -
#
#     phylogenetic classification (Coll et al., 2014)
# 573                   2.2.1.1 Beijing Pacific RD150
# 703                   2.2.1.1 Beijing Pacific RD150
# 767                   2.2.1.1 Beijing Pacific RD150
# 797                                     4.3.2.1 LAM
#
# [4 rows x 22 columns]

# %%
S0267_06

# %%
4.3.2.1 (18), 4.8 (124)

# %%
18/(124+18)
# Out:
# 0.1267605633802817

# %%
sample_id = 'MFS-365'

sample_dir = "/n/data1/hms/dbmi/farhat/rollingDB/TRUST/Illumina_WGS_processed"

bam_file = os.path.join(f"{sample_dir}/{sample_id}/bam/{sample_id}.depth.tsv.gz")
assert os.path.isfile(bam_file)

df_depth = pd.read_csv(bam_file, sep='\t', header=None, compression='gzip')
print(f"{sample_id}: Average depth: {df_depth[2].mean()}, Median depth: {df_depth[2].median()}")
# Out:
# MFS-365: Average depth: 286.75479991984645, Median depth: 292.0

# %%
sample_id = 'MFS-742'

sample_dir = "/n/data1/hms/dbmi/farhat/rollingDB/TRUST/Illumina_WGS_processed"

bam_file = os.path.join(f"{sample_dir}/{sample_id}/bam/{sample_id}.depth.tsv.gz")
assert os.path.isfile(bam_file)

df_depth = pd.read_csv(bam_file, sep='\t', header=None, compression='gzip')
print(f"{sample_id}: Average depth: {df_depth[2].mean()}, Median depth: {df_depth[2].median()}")
# Out:
# MFS-742: Average depth: 310.75091532828054, Median depth: 316.0

# %%
len(df_trust_WGS_metadata), df_trust_WGS_metadata.Original_ID.nunique()
# Out:
# (806, 794)

# %%
df_trust_WGS_metadata.iloc[df_trust_WGS_metadata.index.values[df_trust_WGS_metadata.duplicated(subset='Original_ID', keep=False)]].sort_values(['Original_ID'])[['SampleID', 'Original_ID', 'Excluded', 'quality', 'Report_File', 'Comment', 'comment', 'status']]
# Out:
#     SampleID Original_ID  Excluded  quality  \
# 200  MFS-557    S0073-01       0.0      1.0
# 532  MFS-352    S0073-01       NaN      NaN
# 210  MFS-567    S0099-01       1.0      4.0
# 20   MFS-738    S0099-01       0.0      1.0
# 212  MFS-569    S0102-01       1.0      1.0
# 21   MFS-739    S0102-01       0.0      1.0
# 213  MFS-570    S0102-05       1.0      4.0
# 22   MFS-740    S0102-05       0.0      1.0
# 24   MFS-742    S0114-04       0.0      1.0
# 494  MFS-365    S0114-04       NaN      1.0
# 243  MFS-600    S0137-01       0.0      1.0
# 28   MFS-746    S0137-01       0.0      1.0
# 52   MFS-770    S0360-01       0.0      1.0
# 304  MFS-661    S0360-01       1.0      4.0
# 514  MFS-451    S0364-07       NaN      4.0
# 53   MFS-771    S0364-07       0.0      1.0
# 309  MFS-666    S0385-04       1.0      4.0
# 60   MFS-778    S0385-04       0.0      1.0
# 61   MFS-779    S0395-08       0.0      1.0
# 393  MFS-489    S0395-08       NaN      1.0
# 66   MFS-784    S0402-01       0.0      1.0
# 319  MFS-676    S0402-01       0.0      1.0
# 69   MFS-787    S0405-01       0.0      1.0
# 322  MFS-679    S0405-01       1.0      2.0
#
#                            Report_File Comment  \
# 200         2024-05-27_report.v10.xlsx     NaN
# 532  2023-09-01_report_Farhat.v09.xlsx     NaN
# 210         2024-05-27_report.v10.xlsx     NaN
# 20          2024-11-13_report.v10.xlsx     NaN
# 212         2024-05-27_report.v10.xlsx     NaN
# 21          2024-11-13_report.v10.xlsx     NaN
# 213         2024-05-27_report.v10.xlsx     NaN
# 22          2024-11-13_report.v10.xlsx     NaN
# 24          2024-11-13_report.v10.xlsx     NaN
# 494  2023-09-01_report_Farhat.v09.xlsx     NaN
# 243         2024-05-27_report.v10.xlsx     NaN
# 28          2024-11-13_report.v10.xlsx     NaN
# 52          2024-11-13_report.v10.xlsx     NaN
# 304         2024-05-27_report.v10.xlsx     NaN
# 514  2023-09-01_report_Farhat.v09.xlsx     NaN
# 53          2024-11-13_report.v10.xlsx     NaN
# 309         2024-05-27_report.v10.xlsx     NaN
# 60          2024-11-13_report.v10.xlsx     NaN
# 61          2024-11-13_report.v10.xlsx     NaN
# 393  2023-09-01_report_Farhat.v09.xlsx     NaN
# 66          2024-11-13_report.v10.xlsx     NaN
# 319         2024-05-27_report.v10.xlsx     NaN
# 69          2024-11-13_report.v10.xlsx     NaN
# 322         2024-05-27_report.v10.xlsx     NaN
#
#                                   comment       status
# 200                                   NaN          NaN
# 532  lib failed 2x - Illumina and PacBio-       failed
# 210                                   NaN          NaN
# 20                                    NaN          NaN
# 212                                   NaN          NaN
# 21                                    NaN          NaN
# 213                                   NaN          NaN
# 22                                    NaN          NaN
# 24                                    NaN          NaN
# 494                                     -  in progress
# 243                                   NaN          NaN
# 28                                    NaN          NaN
# 52                                    NaN          NaN
# 304                                   NaN          NaN
# 514                                     -       failed
# 53                                    NaN          NaN
# 309                                   NaN          NaN
# 60                                    NaN          NaN
# 61                                    NaN          NaN
# 393                                     -     finished
# 66                                    NaN          NaN
# 319                                   NaN          NaN
# 69                                    NaN          NaN
# 322                                   NaN          NaN

# %%
# get all Excel files from this directory
trust_report_fNames = glob.glob("/n/data1/hms/dbmi/farhat/rollingDB/TRUST/WGS_metadata_reports/*.xlsx")
print(f"{len(trust_report_fNames)} WGS metadata Excel files")

df_trust_WGS_metadata = []

# sort chronologically because below, we preferentially keep the later one
for fName in np.sort(trust_report_fNames)[::-1]:

    # read in single Excel file
    df = pd.read_excel(fName, sheet_name=None)

    # remove spaces from column name to make querying easier. Also there could be NaN rows if there are additional empty rows in the Excel sheet, so drop them
    df = df['summary'].rename(columns={'original ID': 'Original_ID'}).dropna(axis=0, how='all')

    if 'S0114-04' in df.Original_ID.values:
        print(fName)

    df['Report_File'] = os.path.basename(fName)
    
    # append to list for concatenation
    df_trust_WGS_metadata.append(df)

# the Excel files above are running totals, so the most recent file has data that is also in the older files. So drop duplicates, keeping the most recent (last) one
# also exclude WGS samples that failed
df_trust_WGS_metadata = pd.concat(df_trust_WGS_metadata).drop_duplicates('SampleID', keep='last').reset_index(drop=True)
# Out:
# 5 WGS metadata Excel files
# /n/data1/hms/dbmi/farhat/rollingDB/TRUST/WGS_metadata_reports/2024-11-13_report.v10.xlsx
# /n/data1/hms/dbmi/farhat/rollingDB/TRUST/WGS_metadata_reports/2023-09-01_report_Farhat.v09.xlsx

# %%
df_Sep = pd.read_excel("/n/data1/hms/dbmi/farhat/rollingDB/TRUST/WGS_metadata_reports/2023-09-01_report_Farhat.v09.xlsx", sheet_name=None)['summary'].rename(columns={'original ID': 'Original_ID'}).dropna(axis=0, how='all')

df_Nov = pd.read_excel("/n/data1/hms/dbmi/farhat/rollingDB/TRUST/WGS_metadata_reports/2024-11-13_report.v10.xlsx", sheet_name=None)['summary'].rename(columns={'original ID': 'Original_ID'}).dropna(axis=0, how='all')

# %%
df_Sep.query("Original_ID=='S0114-04'")
# Out:
#     SampleID Original_ID shipment       status comment         SampleLib  \
# 401  MFS-365    S0114-04      3rd  in progress       -  MFS-365_lib59186
#
#     phylogenetic classification (Coll et al., 2014)  quality  Cov Any Mean  \
# 401                                     4.3.2.1 LAM      1.0        217.44
#
#      Cov Unam Perc  Perc. Reads Mapped
# 401            1.0              0.9894

# %%
df_Nov.query("Original_ID=='S0114-04'")
# Out:
#    SampleID         SampleLib Original_ID  Pacbio Comment  quality  \
# 24  MFS-742  MFS-742_lib72905    S0114-04     NaN     NaN      1.0
#
#     Cov Any Mean  Cov Unam Perc  Perc. Reads Mapped  Excluded  \
# 24        321.11            1.0              0.9869       0.0
#
#     repeat_pcrfree_1  transfered_pcrfree  transfered_pacbio  Unnamed: 13  250x
# 24               1.0                 0.0                0.0          NaN   NaN

# %%
# for name in df_trust_patients.dropna(subset='F2').SampleID.values:
#     if not os.path.isfile(f"/n/data1/hms/dbmi/farhat/Sanjana/MIC_data/TRUST/VCF/{name}.vcf"):
#         shutil.copy(f"/n/scratch/users/s/sak0914/TRUST_variant_calling/{name}/pilon/{name}_variants.vcf", f"/n/data1/hms/dbmi/farhat/Sanjana/MIC_data/TRUST/VCF/{name}.vcf")

# pd.Series(glob.glob("/n/data1/hms/dbmi/farhat/Sanjana/MIC_data/TRUST/VCF/*.vcf")).to_csv("/n/data1/hms/dbmi/farhat/Sanjana/MIC_data/TRUST/vcf_full_paths.txt", sep='\t', header=None, index=False)

# %% [markdown]
# # espR Indels Over the course of infection
#
# ### Haoyang's earlier analysis showed higher AF at baseline than at follow-up

# %%
# this is all 452 patients, no exclusions based on the availability of WGS or validity for the TCC analysis
df_full = pd.read_csv("raw_data/20240826_metadata_MIC_method_updates.csv")

# this is all WGS samples that we have matched with patients, not just WGS at baseline
df_full_WGS = pd.read_csv("/n/data1/hms/dbmi/farhat/rollingDB/TRUST/clinical_data/20241127_combined_patients_WGS_samples.csv")

# %%
espR_indel_data = []

vcf_dir = "/n/data1/hms/dbmi/farhat/Sanjana/MIC_data/TRUST/espR_indels"

fNames = glob.glob(f"{vcf_dir}/*.tsv")

for fName in fNames:

    try:
        df_indels = pd.read_csv(fName, sep='\t')
    
        if len(df_indels) > 0:
    
            df_indels['SampleID'] = os.path.basename(fName).split('.')[0]
            espR_indel_data.append(df_indels)
    except:
        print(f"Not finished {fName}")

espR_indel_data = pd.concat(espR_indel_data).reset_index(drop=True)#.merge(df_trust_patients[['pid', 'SampleID']], on='SampleID')

# check to see if any samples have multiple indels
print(f"{espR_indel_data.SampleID.nunique()} samples have {len(espR_indel_data)} indels in espR")

# combine with WGS metadata
espR_indel_data = espR_indel_data.merge(df_full_WGS[['pid', 'SampleID', 'specimen_time_point', 'Coll2014', 'Lineage', 'F2']], how='left').sort_values(['pid', 'specimen_time_point']).reset_index(drop=True)

assert sum(pd.isnull(espR_indel_data['specimen_time_point'])) == 0

espR_indel_data['Lineage'] = espR_indel_data['Lineage'].astype(int).astype(str)

# replace the specimen time point 15 with 1 because it was also collected at baseline
espR_indel_data['specimen_time_point'] = espR_indel_data['specimen_time_point'].replace(15, 1)
# Out:
# 37 samples have 37 indels in espR

# %%
no_baseline_WGS = list(set(espR_indel_data.pid) - set(espR_indel_data.query("specimen_time_point <= 2").pid))
print(f"{len(no_baseline_WGS)} patients don't have sequencing at baseline")

espR_indel_data['baseline'] = (espR_indel_data['specimen_time_point'] <= 2).astype(int)

# don't have sequencing at baseline
espR_indel_data.query("pid in @no_baseline_WGS")
# Out:
# 2 patients don't have sequencing at baseline
#         POS REF ALT FILTER     QUAL    AF   DP  BQ  MQ   IC  DC SampleID  \
# 16  4323354   C  CG    Amb  10192.0  0.59  315  33  60  186   0  MFS-134
# 21  4323354   C  CG   PASS   9653.0  0.97  293  33  60  284   0  MFS-263
#
#       pid  specimen_time_point Coll2014 Lineage        F2  baseline
# 16  T0224                  8.0  2.2.1.1       2  0.138670         0
# 21  T0253                  5.0  2.2.1.1       2  0.013131         0

# %%
espR_indel_data.shape
# Out:
# (37, 18)

# %%
for pid in espR_indel_data.pid.unique():

    if len(espR_indel_data.query("pid==@pid")) == 1:

        # this means that there is sequencing for the patient at another time point, but it doesn't have an espR indel, so add it to the dataframe
        if len(df_full_WGS.query("pid==@pid")) > 1:

            # find the additional samples (not in espR_indel_data already)
            add_samples = df_full_WGS.query("pid==@pid & SampleID not in @espR_indel_data.SampleID")

            assert len(add_samples) == 1
            
            df_add = pd.DataFrame({'POS': np.nan,
                                   'REF': np.nan,
                                   'ALT': np.nan,
                                   'QUAL': np.nan,
                                   'AF': 0,
                                   'DP': 0,
                                   'BQ': np.nan,
                                   'MQ': np.nan,
                                   'IC': 0,
                                   'DC': 0,
                                   'SampleID': add_samples['SampleID'].values[0],
                                   'pid': pid,
                                   'specimen_time_point': add_samples['specimen_time_point'].values[0],
                                   'Coll2014': add_samples['Coll2014'].values[0],
                                   'Lineage': add_samples['Lineage'].values[0],
                                   'F2': add_samples['F2'].values[0],
                                   'baseline': 0
                                  }, index=[-1])
            
            espR_indel_data = pd.concat([espR_indel_data, df_add])

espR_indel_data = espR_indel_data.sort_values(['pid', 'specimen_time_point']).reset_index(drop=True)

# %%
espR_indel_data.query("F2 > 0.03")
# Out:
#           POS REF ALT FILTER     QUAL    AF   DP    BQ    MQ   IC  DC  \
# 13  4323354.0   C  CG   PASS   8635.0  0.83  260  33.0  60.0  216   0
# 18  4323354.0   C  CG    Amb  10192.0  0.59  315  33.0  60.0  186   0
# 35  4323354.0   C  CG   PASS   3734.0  0.83  363  34.0  60.0  300   0
#
#    SampleID    pid  specimen_time_point Coll2014 Lineage        F2  baseline
# 13  MFS-608  T0152                  1.0    4.3.3       4  0.155607         1
# 18  MFS-134  T0224                  8.0  2.2.1.1       2  0.138670         0
# 35  MFS-705  T0441                  1.0  2.2.1.1       2  0.154881         1

# %%
# espR_indel_data_multiple_WGS = pd.DataFrame(espR_indel_data.groupby("pid")['SampleID'].nunique()).reset_index().query("SampleID > 1").pid.values

# espR_indel_data_multiple_WGS = espR_indel_data.query("pid in @espR_indel_data_multiple_WGS")

# %%
espR_indel_data
# Out:
#           POS  REF  ALT FILTER     QUAL    AF   DP    BQ    MQ   IC  DC  \
# 0   4323354.0    C   CG   PASS  10266.0  0.97  308  33.0  60.0  299   0
# 1   4323354.0    C   CG   PASS   8838.0  0.98  265  33.0  60.0  259   0
# 2   4323354.0    C   CG   PASS  10907.0  0.98  325  34.0  60.0  318   0
# 3   4323354.0    C   CG   PASS   8155.0  0.98  247  33.0  60.0  243   0
# 4   4323354.0    C   CG   PASS  11508.0  0.98  341  34.0  60.0  335   0
# 5   4323354.0    C   CG   PASS   8317.0  0.98  248  34.0  60.0  243   0
# 6   4323354.0    C   CG   PASS   8665.0  0.97  271  32.0  60.0  261   0
# 7   4323354.0    C   CG    Amb   9741.0  0.33  296  33.0  60.0   99   0
# 8   4323354.0    C   CG   PASS  12457.0  0.99  376  33.0  60.0  370   0
# 9   4323354.0    C   CG   PASS  11431.0  0.98  341  34.0  60.0  334   0
# 10  4323354.0    C   CG   PASS   8521.0  0.98  252  34.0  60.0  246   0
# 11  4323354.0    C   CG   PASS   8430.0  0.98  253  33.0  60.0  246   0
# 12  4323354.0    C   CG   PASS  11317.0  0.99  340  33.0  60.0  336   0
# 13  4323354.0    C   CG   PASS   8635.0  0.83  260  33.0  60.0  216   0
# 14        NaN  NaN  NaN    NaN      NaN  0.00    0   NaN   NaN    0   0
# 15  4323354.0    C   CG   PASS   9192.0  0.96  279  33.0  60.0  268   0
# 16  4323354.0    C   CG   PASS  11212.0  0.98  339  33.0  60.0  331   0
# 17        NaN  NaN  NaN    NaN      NaN  0.00    0   NaN   NaN    0   0
# 18  4323354.0    C   CG    Amb  10192.0  0.59  315  33.0  60.0  186   0
# 19  4323353.0    T   TC   PASS  11295.0  0.99  341  33.0  60.0  337   0
# 20  4323353.0    T   TC   PASS   9605.0  1.00  289  33.0  60.0  289   0
# 21  4323354.0    C   CG   PASS   9478.0  0.97  283  33.0  60.0  275   0
# 22  4323354.0    C   CG   PASS   9989.0  0.98  307  33.0  60.0  300   0
# 23        NaN  NaN  NaN    NaN      NaN  0.00    0   NaN   NaN    0   0
# 24  4323354.0    C   CG   PASS   9653.0  0.97  293  33.0  60.0  284   0
# 25  4323354.0    C   CG   PASS   9200.0  0.96  282  33.0  60.0  272   0
# 26  4323354.0    C   CG   PASS  11686.0  0.98  317  37.0  60.0  309   0
# 27  4323354.0    C   CG   PASS   9955.0  0.97  306  33.0  60.0  295   0
# 28  4323354.0    C   CG   PASS   9601.0  0.96  295  33.0  60.0  281   0
# 29  4323354.0    C   CG   PASS   8743.0  0.99  265  33.0  60.0  262   0
# 30  4323354.0    C   CG   PASS   9815.0  0.97  294  33.0  60.0  285   0
# 31  4323354.0    C   CG   PASS   9341.0  0.97  281  33.0  60.0  273   0
# 32  4323354.0    C   CG   PASS   7999.0  0.98  238  34.0  60.0  234   0
# 33  4323354.0    C   CG   PASS   8877.0  1.00  266  33.0  60.0  265   0
# 34  4323354.0    C   CG   PASS   9455.0  0.97  258  37.0  60.0  251   0
# 35  4323354.0    C   CG   PASS   3734.0  0.83  363  34.0  60.0  300   0
# 36  4323354.0    C   CG   PASS  12899.0  0.97  383  34.0  60.0  372   0
# 37  4323354.0    C   CG   PASS  10776.0  0.95  291  37.0  60.0  276   0
# 38  4323354.0    C   CG   PASS  16939.0  0.70  466  36.0  60.0  327   0
# 39  4323354.0    C   CG   PASS  19325.0  0.97  539  36.0  60.0  523   0
#
#    SampleID    pid  specimen_time_point   Coll2014 Lineage        F2  baseline
# 0    MFS-22  T0041                  1.0    2.2.1.1       2  0.009680         1
# 1    MFS-30  T0052                  1.0    2.2.1.1       2  0.009991         1
# 2    MFS-31  T0052                  6.0    2.2.1.1       2  0.010668         0
# 3    MFS-32  T0053                  1.0    2.2.1.1       2  0.011590         1
# 4   MFS-555  T0071                  1.0    2.2.1.1       2  0.010615         1
# 5   MFS-556  T0071                  5.0    2.2.1.1       2  0.010171         0
# 6    MFS-54  T0089                  1.0    2.2.1.1       2  0.010112         1
# 7   MFS-355  T0090                  1.0    2.2.1.1       2  0.011483         1
# 8   MFS-356  T0090                  6.0    2.2.1.1       2  0.010696         0
# 9   MFS-592  T0127                  1.0    2.2.1.1       2  0.010155         1
# 10  MFS-593  T0127                  8.0    2.2.1.1       2  0.010659         0
# 11  MFS-369  T0136                  1.0    2.2.1.1       2  0.011555         1
# 12  MFS-599  T0136                  7.0    2.2.1.1       2  0.010112         0
# 13  MFS-608  T0152                  1.0      4.3.3       4  0.155607         1
# 14  MFS-609  T0152                  4.0  4.3.4.2.1       4  0.003707         0
# 15   MFS-93  T0176                  1.0    2.2.1.1       2  0.011959         1
# 16   MFS-94  T0176                  6.0    2.2.1.1       2  0.010339         0
# 17  MFS-133  T0224                  1.0      2.2.1       2  0.012533         0
# 18  MFS-134  T0224                  8.0    2.2.1.1       2  0.138670         0
# 19  MFS-381  T0227                  2.0    4.1.1.1       4  0.007652         1
# 20  MFS-136  T0227                  7.0    4.1.1.1       4  0.007964         0
# 21  MFS-138  T0230                  1.0    2.2.1.1       2  0.010892         1
# 22  MFS-139  T0230                  5.0    2.2.1.1       2  0.011428         0
# 23  MFS-281  T0253                  1.0        4.8     4.0  0.023156         0
# 24  MFS-263  T0253                  5.0    2.2.1.1       2  0.013131         0
# 25  MFS-274  T0263                  1.0    2.2.1.1       2  0.011353         1
# 26  MFS-764  T0298                  1.0      4.3.3       4  0.005125         1
# 27  MFS-315  T0310                  1.0    2.2.1.1       2  0.012944         1
# 28  MFS-316  T0310                  7.0    2.2.1.1       2  0.011899         0
# 29  MFS-418  T0342                  1.0    2.2.1.1       2  0.010373         1
# 30  MFS-419  T0342                  5.0    2.2.1.1       2  0.010598         0
# 31  MFS-448  T0363                  1.0    2.2.1.1       2  0.009318         1
# 32  MFS-449  T0363                  8.0    2.2.1.1       2  0.011304         0
# 33  MFS-479  T0385                  1.0    2.2.1.1       2  0.010507         1
# 34  MFS-778  T0385                  4.0    2.2.1.1       2  0.011717         0
# 35  MFS-705  T0441                  1.0    2.2.1.1       2  0.154881         1
# 36  MFS-708  T0446                  1.0    2.2.1.1       2  0.011488         1
# 37  MFS-826  T0446                  4.0    2.2.1.1       2  0.011893         0
# 38  MFS-866  T0475                  1.0    2.2.1.1       2  0.011800         1
# 39  MFS-867  T0475                  6.0    2.2.1.1       2  0.010622         0

# %%
bcftools filter -i "POS >= 4323235 & POS <= 4323897" MFS-609_variants.vcf

# %%
espR_indel_data.query("SampleID=='MFS-609'")
# Out:
# Empty DataFrame
# Columns: [POS, REF, ALT, FILTER, QUAL, AF, DP, BQ, MQ, IC, DC, SampleID, pid, specimen_time_point, Coll2014, Lineage, F2, baseline]
# Index: []

# %%
espR_indel_data.query("pid=='T0152'")
# Out:
#         POS REF ALT FILTER    QUAL    AF   DP  BQ  MQ   IC  DC SampleID  \
# 13  4323354   C  CG   PASS  8635.0  0.83  260  33  60  216   0  MFS-608
#
#       pid  specimen_time_point Coll2014 Lineage        F2  baseline
# 13  T0152                  1.0    4.3.3       4  0.155607         1

# %%
df_full_WGS.query("pid=='T0152'")
# Out:
#        pid Original_ID SampleID  specimen_time_point         SampleLib  \
# 279  T0152    S0152-01  MFS-608                  1.0  MFS-608_lib66001
# 280  T0152    S0152-04  MFS-609                  4.0  MFS-609_lib66002
#
#      Pacbio Comment  quality  Cov_Any_Mean  Cov_Unam_Perc  ...      fib4  \
# 279     NaN     NaN      1.0        263.42           1.00  ...  0.512251
# 280     NaN     NaN      1.0        263.17           0.99  ...  0.512251
#
#      prevtb_outcome  total_adherence  adherence_12week  first_dots_date  \
# 279             NaN         0.868852          0.946429                2
# 280             NaN         0.868852          0.946429                2
#
#      last_dots_date        F2   Coll2014       Freschi2020 Lineage
# 279             181  0.155607      4.3.3  4.2.1.2.1.1.i4.1       4
# 280             181  0.003707  4.3.4.2.1  4.2.1.2.1.1.i3.1       4
#
# [2 rows x 7102 columns]

# %%
espR_indel_data.query("pid not in @no_baseline_WGS & FILTER != 'PASS'")
# Out:
#        POS REF ALT FILTER    QUAL    AF   DP  BQ  MQ  IC  DC SampleID    pid  \
# 7  4323354   C  CG    Amb  9741.0  0.33  296  33  60  99   0  MFS-355  T0090
#
#    specimen_time_point Coll2014 Lineage        F2  baseline
# 7                  1.0  2.2.1.1       2  0.011483         1

# %%
df_full_WGS.query("pid=='T0090'")
# Out:
#        pid Original_ID SampleID  specimen_time_point         SampleLib  \
# 369  T0090    S0090-06  MFS-356                  6.0  MFS-356_lib59080
# 370  T0090    S0090-01  MFS-355                  1.0  MFS-355_lib59079
#
#      Pacbio Comment  quality  Cov_Any_Mean  Cov_Unam_Perc  ...      fib4  \
# 369     NaN     NaN      1.0        376.28           0.99  ...  0.552999
# 370     NaN     NaN      1.0        308.78           0.99  ...  0.552999
#
#      prevtb_outcome  total_adherence  adherence_12week  first_dots_date  \
# 369             NaN          0.95122          0.949153                3
# 370             NaN          0.95122          0.949153                3
#
#      last_dots_date        F2 Coll2014 Freschi2020 Lineage
# 369             183  0.010696  2.2.1.1   2.2.1.1.1       2
# 370             183  0.011483  2.2.1.1   2.2.1.1.1       2
#
# [2 rows x 7102 columns]

# %%
pd.DataFrame(espR_indel_data.query("pid not in @no_baseline_WGS").groupby("pid")['SampleID'].nunique()).query("SampleID > 1").shape
# Out:
# (14, 1)

# %%
espR_indel_data.groupby("baseline")['AF'].mean()
# Out:
# baseline
# 0    0.952500
# 1    0.918571
# Name: AF, dtype: float64

# %% [markdown]
# # Analysis
#
# ## 1. Do individual patients WGS samples reflect different lineages throughout the course of treatment?

# %%
pids_multiple_sequencing = pd.DataFrame(df_WGS_metadata.groupby(['pid'])['Lineage'].count()).query("Lineage > 1").index.values

len(pids_multiple_sequencing)
# Out:
# 227

# %%
df_WGS_metadata.query("pid in @pids_multiple_sequencing")[['pid', 'SampleID', 'F2', 'Coll2014', 'Lineage', 'specimen_num']].sort_values(['pid', 'SampleID'])
# Out:
#        pid SampleID        F2 Coll2014 Lineage specimen_num
# 408  T0002  MFS-509  0.006467      4.8       4            1
# 409  T0002  MFS-510  0.007872      4.8       4            5
# 410  T0003  MFS-511  0.009607    2.2.1       2            1
# 411  T0003  MFS-512  0.010150    2.2.1       2            8
# 0    T0004    MFS-1  0.011212  2.2.1.1       2            1
# ..     ...      ...       ...      ...     ...          ...
# 404  T0393  MFS-486  0.035298  2.2.1.1       2            6
# 405  T0394  MFS-487  0.007957  4.1.1.1       4            1
# 406  T0394  MFS-488  0.008102  4.1.1.1       4            7
# 407  T0395  MFS-489  0.006334    4.3.3       4            8
# 559  T0395  MFS-670  0.007892    4.3.3       4            1
#
# [458 rows x 6 columns]

# %%
# pd.DataFrame(({'a': ['MFS-188', 'MFS-605'],
#                'b': ['MFS-188', 'MFS-605'],
#                'c': [0, 0]
#               })).to_csv("/home/sak0914/Mtb_Megapipe/TRUST/isolates_to_run.tsv", sep='\t', header=None, index=False)

# %%
df_WGS_metadata['specimen_num'].value_counts(dropna=False)
# Out:
# specimen_num
# 1     341
# 8      73
# 6      49
# 7      49
# 5      35
# 4      20
# 2      19
# 9      13
# 15      2
# 13      2
# 11      1
# Name: count, dtype: int64

# %%
lineages_per_pid = pd.DataFrame(df_WGS_metadata.groupby(['pid'])['Lineage'].nunique()).reset_index()
pids_multiple_lineages = lineages_per_pid.query("Lineage > 1").pid.values
len(pids_multiple_lineages)
# Out:
# 11

# %%
df_plot_lineage_diff_during_tx = df_WGS_metadata.query("pid in @pids_multiple_lineages")[['pid', 'SampleID', 'F2', 'Coll2014', 'Lineage', 'specimen_num']].sort_values(['pid', 'SampleID'])#.query("~Lineage.str.contains(',')")

# %%
df_plot_lineage_diff_during_tx
# Out:
#        pid SampleID        F2         Coll2014 Lineage specimen_num
# 267  T0010  MFS-336  0.458952  4.1.1.1,2.2.1.1     2,4            1
# 268  T0010  MFS-337  0.012046          2.2.1.1       2            8
# 4    T0013    MFS-5  0.011966            3.1.1       3            1
# 5    T0013    MFS-6  0.008787          4.3.2.1       4            9
# 459  T0080  MFS-560  0.003377        4.3.4.2.1       4            1
# 460  T0080  MFS-561  0.009970          2.2.1.1       2            6
# 82   T0167   MFS-84  0.177757            2.2.1       2            1
# 83   T0167   MFS-85  0.259418    2.2.1,4.1.1.3     2,4            4
# 522  T0204  MFS-630  0.147559            2.2.1       2            1
# 523  T0204  MFS-631  0.314259      2.2.1,3.1.1     2,3            8
# 524  T0204  MFS-632  0.008530            2.2.1       2           13
# 142  T0235  MFS-144  0.012629          2.2.1.1       2            1
# 143  T0235  MFS-145  0.122113              4.8       4            5
# 195  T0253  MFS-263  0.013131          2.2.1.1       2            5
# 213  T0253  MFS-281  0.023156              4.8       4            1
# 202  T0267  MFS-270  0.245979          2.2.1.1       2            1
# 212  T0267  MFS-280  0.011335          4.3.2.1       4            6
# 244  T0305  MFS-313  0.436810  4.3.2.1,2.2.1.1     2,4            1
# 245  T0305  MFS-314  0.011400          4.3.2.1       4            8
# 248  T0311  MFS-317  0.369685  4.3.2.1,2.2.1.1     2,4            1
# 249  T0311  MFS-318  0.012310          2.2.1.1       2            8
# 375  T0367  MFS-456  0.130840          2.2.1.1       2            1
# 376  T0367  MFS-457  0.012279                3       3            7

# %%
# Assuming df['Lineage'] contains your lineage values
unique_lineages = df_plot_lineage_diff_during_tx['Lineage'].unique()

# Use a colormap to generate colors
colors = plt.cm.tab10(range(len(unique_lineages)))  # You can replace `tab10` with other colormaps

# Create the color dictionary
color_dict = {lineage: color for lineage, color in zip(unique_lineages, colors)}


# Set up the figure and axis
fig, ax = plt.subplots(figsize=(8, len(df_plot_lineage_diff_during_tx['pid'].unique()) * 0.5))

# Iterate over each pid and plot lines between the two sample points
for pid in df_plot_lineage_diff_during_tx['pid'].unique():

    df_pid = df_plot_lineage_diff_during_tx.query("pid==@pid").sort_values(by='specimen_num')
    
    # Plot a line connecting the two F2 points for this pid
    ax.plot(
        df_pid['F2'],
        [pid] * len(df_pid),
        linestyle='-', 
        color='gray',  # Line color connecting the points (optional)
        zorder=1
    )
    
    # Plot each point individually with its color from Lineage
    for _, row in df_pid.iterrows():
        ax.scatter(
            row['F2'], 
            pid, 
            color=color_dict.get(row['Lineage'], 'gray'),  # Color based on Lineage
            s=100,  # Adjust point size if needed
            edgecolor='black',  # Optional: add border for visibility
            zorder=2
        )
        
        # # Optionally add annotations for SampleID at each point
        # ax.text(
        #     row['F2'],
        #     pid,
        #     f"{row['SampleID']}",
        #     ha='center',
        #     va='bottom',
        #     fontsize=9,
        #     color='black'
        # )

# Customize the plot
ax.set_yticks(df_plot_lineage_diff_during_tx['pid'].unique())  # Set y-axis to show each pid
ax.set_xlabel('Lineage')
ax.set_ylabel('pid')
plt.title("Lineage Connections by Sample for Each pid")
plt.legend()

# Display the plot
plt.show()

# %%
def plot_pid_lines_with_arrows(df, color_dict):
    fig, ax = plt.subplots(figsize=(8, len(df['pid'].unique()) * 0.5))

    for pid, group in df.groupby('pid'):

        group = group.sort_values(by='specimen_num')
        
        # Extract values for F2 and Lineage for plotting
        x_values = group['F2'].values
        y_value = pid  # This will be the same for both points
        lineages = group['Lineage'].values
        
        # Plot the points for each sample, coloring by Lineage
        ax.plot(x_values, [y_value]*len(x_values), color='gray', linestyle='-', linewidth=1, marker='o')
        
        # Plot each point with its lineage color
        for i, (x, lineage) in enumerate(zip(x_values, lineages)):
            ax.plot(x, y_value, 'o', color=color_dict[lineage], label=lineage if i == 0 else "")
        
        # Add an arrow from the first to the second point
        ax.annotate(
            '', xy=(x_values[1], y_value), xytext=(x_values[0], y_value),
            arrowprops=dict(arrowstyle='->', color='black', lw=1.5)
        )

    # Customize the plot appearance
    ax.set_yticks(df['pid'].unique())
    ax.set_yticklabels(df['pid'].unique())
    ax.set_xlabel('F2')
    ax.set_title('Patient Lineage Progression with Directional Arrows')
    plt.legend()

    plt.gca().invert_yaxis()  # Optional, to match typical plot conventions
    plt.show()

# %%
# Assuming `color_dict` is already created
plot_pid_lines_with_arrows(df_plot_lineage_diff_during_tx, color_dict)

# %% [markdown]
# ## 2. Do re-enrolled patients have different or same lineages during their second (or third) infection?

# %%
df_WGS_metadata.query("pid=='T0272'")
# Out:
#        pid SampleID Original_ID  Kraken_Unclassified_Percent  Median_Depth  \
# 211  T0272  MFS-279    S0272-09                         0.62         330.0
# 309  T0272  MFS-383    S0272-02                         0.39         270.0
#
#      Prop_Sites_10x  Prop_Sites_20x        F2 Coll2014 Freschi2020  \
# 211        0.984225        0.983802  0.009560    2.2.1   2.2.1.1.1
# 309        0.984104        0.983746  0.009333    2.2.1   2.2.1.1.1
#
#       Lipworth2019 Shitikov2017 Stucki2016 Lineage sample_num
# 211  beijing,mungi     lin2.2.1        NaN       2         09
# 309  beijing,mungi     lin2.2.1        NaN       2         02

# %%
df_WGS_metadata.query("pid=='T0263'")
# Out:
#        pid SampleID Original_ID  Kraken_Unclassified_Percent  Median_Depth  \
# 206  T0263  MFS-274   S0263-01A                         0.57         295.0
#
#      Prop_Sites_10x  Prop_Sites_20x        F2 Coll2014 Freschi2020  \
# 206        0.985309        0.984938  0.011353  2.2.1.1   2.2.1.1.1
#
#       Lipworth2019            Shitikov2017 Stucki2016 Lineage sample_num
# 206  beijing,mungi  lin2.2.1,pacific_RD150        NaN       2        01A

# %%
df_WGS_metadata.query("pid=='T0271'")
# Out:
#        pid SampleID Original_ID  Kraken_Unclassified_Percent  Median_Depth  \
# 200  T0271  MFS-268    S0271-05                         0.48         291.0
# 208  T0271  MFS-276   S0271-01A                         0.58         313.0
#
#      Prop_Sites_10x  Prop_Sites_20x        F2 Coll2014 Freschi2020  \
# 200        0.985530        0.985193  0.012523  2.2.1.1   2.2.1.1.1
# 208        0.985776        0.985391  0.010859  2.2.1.1   2.2.1.1.1
#
#       Lipworth2019            Shitikov2017 Stucki2016 Lineage sample_num
# 200        beijing  lin2.2.1,pacific_RD150        NaN       2         05
# 208  beijing,mungi  lin2.2.1,pacific_RD150        NaN       2        01A

# %%
df_full[['pid', 'culture_conversion_sputum_specimen_15']].dropna().query("culture_conversion_sputum_specimen_15.str.contains('tb_positive')")
# Out:
#        pid culture_conversion_sputum_specimen_15
# 237  T0252                           tb_positive

# %%
df_full[['pid', 'culture_conversion_sputum_specimen_13']].dropna().query("culture_conversion_sputum_specimen_13.str.contains('tb_positive')")
# Out:
#        pid culture_conversion_sputum_specimen_13
# 191  T0204                           tb_positive
# 257  T0272                           tb_positive
# 311  T0330                           tb_positive

# %%
df_full.columns[df_full.columns.str.contains('culture_conversion')]
# Out:
# Index(['culture_conversion_sputum_specimen_1',
#        'culture_conversion_sputum_specimen_10',
#        'culture_conversion_sputum_specimen_11',
#        'culture_conversion_sputum_specimen_12',
#        'culture_conversion_sputum_specimen_13',
#        'culture_conversion_sputum_specimen_14',
#        'culture_conversion_sputum_specimen_15',
#        'culture_conversion_sputum_specimen_16',
#        'culture_conversion_sputum_specimen_17',
#        'culture_conversion_sputum_specimen_18',
#        'culture_conversion_sputum_specimen_2',
#        'culture_conversion_sputum_specimen_3',
#        'culture_conversion_sputum_specimen_4',
#        'culture_conversion_sputum_specimen_5',
#        'culture_conversion_sputum_specimen_6',
#        'culture_conversion_sputum_specimen_7',
#        'culture_conversion_sputum_specimen_8',
#        'culture_conversion_sputum_specimen_9'],
#       dtype='object')

# %%
samples_per_pid = pd.DataFrame(df_WGS_metadata.groupby("pid")['SampleID'].count()).reset_index()

# %%
samples_per_pid.query("SampleID > 1")
# Out:
#        pid  SampleID
# 1    T0002         2
# 2    T0003         2
# 3    T0004         2
# 4    T0005         2
# 6    T0008         2
# ..     ...       ...
# 318  T0389         2
# 321  T0392         2
# 322  T0393         2
# 323  T0394         2
# 324  T0395         2
#
# [227 rows x 2 columns]

# %%
df_trust_WGS_metadata.query("SampleID=='MFS-717'")
# Out:
#     SampleID         SampleLib Original_ID  Pacbio Comment  quality  \
# 208  MFS-717  MFS-717_lib66590    S0456-01     NaN     NaN      1.0
#
#      Cov Any Mean  Cov Unam Perc  Perc. Reads Mapped  Excluded  repeat_pacbio  \
# 208        218.63           0.99              0.9861       0.0            NaN
#
#      transfered_pcrfree  transfered_pacbio  repeat_pcrfree shipment status  \
# 208                 NaN                NaN             1.0      NaN    NaN
#
#     comment phylogenetic classification (Coll et al., 2014)
# 208     NaN                                             NaN

# %%
df_pid_with_lineage = df_trust_patients[['pid', 'SampleID', 'Coll2014', 'Lineage', 'F2']].dropna(subset='Lineage').drop_duplicates(subset='pid')

for col in df_pid_with_lineage.columns:
    if col != 'pid':
        df_pid_with_lineage.rename(columns={col: f'pid_{col}'}, inplace=True)

df_screen_prevpid_with_lineage = df_trust_patients[['pid', 'SampleID', 'Coll2014', 'Lineage', 'F2']].dropna(subset='Lineage').drop_duplicates(subset='pid')

for col in df_screen_prevpid_with_lineage.columns:
    if col != 'pid':
        df_screen_prevpid_with_lineage.rename(columns={col: f'screen_prevpid_{col}'}, inplace=True)
    else:
        df_screen_prevpid_with_lineage.rename(columns={col: 'screen_prevpid'}, inplace=True)

# %%
df_pid_with_lineage
# Out:
#        pid pid_SampleID pid_Coll2014 pid_Lineage    pid_F2
# 0    T0002      MFS-509          4.8         4.0  0.006467
# 2    T0003      MFS-511        2.2.1         2.0  0.009607
# 4    T0008      MFS-513      4.1.1.1         4.0  0.006976
# 6    T0011      MFS-514      2.2.1.1         2.0  0.010864
# 8    T0012      MFS-516      4.1.1.3         4.0  0.017793
# ..     ...          ...          ...         ...       ...
# 622  T0290      MFS-264      2.2.1.1           2  0.013014
# 624  T0203      MFS-278        2.2.1           2  0.012411
# 625  T0312      MFS-290            3           3  0.013378
# 627  T0295      MFS-284      2.2.1.1           2  0.012322
# 628  T0286      MFS-302      2.2.1.1           2  0.012861
#
# [367 rows x 5 columns]

# %%
df_screen_prevpid_with_lineage
# Out:
#     screen_prevpid screen_prevpid_SampleID screen_prevpid_Coll2014  \
# 0            T0002                 MFS-509                     4.8
# 2            T0003                 MFS-511                   2.2.1
# 4            T0008                 MFS-513                 4.1.1.1
# 6            T0011                 MFS-514                 2.2.1.1
# 8            T0012                 MFS-516                 4.1.1.3
# ..             ...                     ...                     ...
# 622          T0290                 MFS-264                 2.2.1.1
# 624          T0203                 MFS-278                   2.2.1
# 625          T0312                 MFS-290                       3
# 627          T0295                 MFS-284                 2.2.1.1
# 628          T0286                 MFS-302                 2.2.1.1
#
#     screen_prevpid_Lineage  screen_prevpid_F2
# 0                      4.0           0.006467
# 2                      2.0           0.009607
# 4                      4.0           0.006976
# 6                      2.0           0.010864
# 8                      4.0           0.017793
# ..                     ...                ...
# 622                      2           0.013014
# 624                      2           0.012411
# 625                      3           0.013378
# 627                      2           0.012322
# 628                      2           0.012861
#
# [367 rows x 5 columns]

# %%
df_reenroll_with_dates.merge(df_trust_patients[['pid', 'SampleID', 'Coll2014', 'Lineage', 'F2']].dropna(subset='Lineage').drop_duplicates(subset='pid'), how='left')
# Out:
#       pid screen_prevpid pid_screen_date screen_prevpid_screen_date  \
# 0   T0254          T0210      2021-02-05                 2019-12-18
# 1   T0267          T0066      2021-05-07                 2018-05-07
# 2   T0275          T0194      2021-05-26                 2019-09-25
# 3   T0279          T0103      2021-06-28                 2018-09-11
# 4   T0281          T0032      2021-08-03                 2017-11-22
# 5   T0330          T0257      2022-02-17                 2021-03-04
# 6   T0336          T0249      2022-04-25                 2021-01-05
# 7   T0340          T0176      2022-06-08                 2019-07-19
# 8   T0348          T0191      2022-07-04                 2019-09-19
# 9   T0363          T0130      2022-09-01                 2018-12-11
# 10  T0377          T0078      2022-10-24                 2018-06-20
# 11  T0380          T0202      2022-10-27                 2019-10-17
# 12  T0387          T0210      2022-11-25                 2019-12-18
# 13  T0387          T0254      2022-11-25                 2021-02-05
# 14  T0424          T0115      2023-05-19                 2018-10-30
# 15  T0435          T0089      2023-06-27                 2018-07-20
# 16  T0438          T0040      2023-06-29                 2017-12-14
# 17  T0451          T0039      2023-07-20                 2017-12-13
# 18  T0453          T0290      2023-07-25                 2021-08-27
#
#     screening_diff SampleID Coll2014 Lineage        F2
# 0            415.0  MFS-170  2.2.1.1       2  0.011597
# 1           1096.0  MFS-270  2.2.1.1       2  0.245979
# 2            609.0      NaN      NaN     NaN       NaN
# 3           1021.0  MFS-298  4.3.2.1       4  0.013741
# 4           1350.0      NaN      NaN     NaN       NaN
# 5            350.0  MFS-660  4.1.1.1       4  0.006470
# 6            475.0  MFS-407    2.2.1       2  0.009269
# 7           1055.0  MFS-415  2.2.1.1       2  0.011610
# 8           1019.0      NaN      NaN     NaN       NaN
# 9           1360.0  MFS-448  2.2.1.1       2  0.009318
# 10          1587.0  MFS-470  4.1.1.1       4  0.008630
# 11          1106.0  MFS-474    2.2.1       2  0.008621
# 12          1073.0  MFS-667  2.2.1.1       2  0.011896
# 13           658.0  MFS-667  2.2.1.1       2  0.011896
# 14          1662.0  MFS-694    2.2.1       2  0.009814
# 15          1803.0  MFS-700  2.2.1.1       2  0.009888
# 16          2023.0      NaN      NaN     NaN       NaN
# 17          2045.0  MFS-713  2.2.1.1       2  0.010139
# 18           697.0  MFS-715  2.2.1.1       2  0.009421
